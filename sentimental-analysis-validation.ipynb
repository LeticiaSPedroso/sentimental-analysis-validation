# %% [markdown]
# Análise de sentimentos com validação

# %%
import pandas as pd 
import sklearn
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.stem import RSLPStemmer
import re

# %%
df1 = pd.read_table('/home/leticia/classify_texts/sentimentanalysis/imdb_labelled.txt',names = ['text', 'labels'],sep = ' \t')

df2 = pd.read_table('/home/leticia/classify_texts/sentimentanalysis/amazon_cells_labelled.txt',sep ='\t',names = ['text', 'labels'])

df3 = pd.read_table('/home/leticia/classify_texts/sentimentanalysis/yelp_labelled.txt',sep ='\t',names = ['text', 'labels'])

df = pd.concat([df1,df2,df3])

print (df)
# Out:
#                                                   text  labels
# 0    A very, very, very slow-moving, aimless movie ...       0
# 1    Not sure who was more lost - the flat characte...       0
# 2    Attempting artiness with black & white and cle...       0
# 3          Very little music or anything to speak of.        0
# 4    The best scene in the movie was when Gerardo i...       1
# 5    The rest of the movie lacks art, charm, meanin...       0
# 6                                   Wasted two hours.        0
# 7    Saw the movie today and thought it was a good ...       1
# 8                                  A bit predictable.        0
# 9    Loved the casting of Jimmy Buffet as the scien...       1
# 10                 And those baby owls were adorable.        1
# 11   The movie showed a lot of Florida at it's best...       1
# 12   The Songs Were The Best And The Muppets Were S...       1
# 13                                    It Was So Cool.        1
# 14   This is a very "right on case" movie that deli...       1
# 15   It had some average acting from the main perso...       0
# 16   This review is long overdue, since I consider ...       1
# 17   I'll put this gem up against any movie in term...       1
# 18   It's practically perfect in all of them Â– a t...       1
# 19   " The structure of this film is easily the mos...       1
# 20   I can think of no other film where something v...       1
# 21   In other words, the content level of this film...       1
# 22   How can anyone in their right mind ask for any...       1
# 23   It's quite simply the highest, most superlativ...       1
# 24   Yes, this film does require a rather significa...       1
# 25        This short film certainly pulls no punches.        0
# 26    Graphics is far from the best part of the game.        0
# 27   This is the number one best TH game in the ser...       1
# 28                           It deserves strong love.        1
# 29                              It is an insane game.        1
# ..                                                 ...     ...
# 970  I immediately said I wanted to talk to the man...       0
# 971                    The ambiance isn't much better.       0
# 972  Unfortunately, it only set us up for disapppoi...       0
# 973                              The food wasn't good.       0
# 974  Your servers suck, wait, correction, our serve...       0
# 975      What happened next was pretty....off putting.       0
# 976  too bad cause I know it's family owned, I real...       0
# 977               Overpriced for what you are getting.       0
# 978               I vomited in the bathroom mid lunch.       0
# 979  I kept looking at the time and it had soon bec...       0
# 980  I have been to very few places to eat that und...       0
# 981  We started with the tuna sashimi which was bro...       0
# 982                            Food was below average.       0
# 983  It sure does beat the nachos at the movies but...       0
# 984       All in all, Ha Long Bay was a bit of a flop.       0
# 985  The problem I have is that they charge $11.99 ...       0
# 986  Shrimp- When I unwrapped it (I live only 1/2 a...       0
# 987     It lacked flavor, seemed undercooked, and dry.       0
# 988  It really is impressive that the place hasn't ...       0
# 989  I would avoid this place if you are staying in...       0
# 990  The refried beans that came with my meal were ...       0
# 991         Spend your money and time some place else.       0
# 992  A lady at the table next to us found a live gr...       0
# 993            the presentation of the food was awful.       0
# 994           I can't tell you how disappointed I was.       0
# 995  I think food should have flavor and texture an...       0
# 996                           Appetite instantly gone.       0
# 997  Overall I was not impressed and would not go b...       0
# 998  The whole experience was underwhelming, and I ...       0
# 999  Then, as if I hadn't wasted enough of my life ...       0
#
# [3000 rows x 2 columns]
# /home/leticia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
def Tokenize(sentence):
    sentence = sentence.lower()
    sentence = nltk.word_tokenize(sentence)
    return sentence

# %%
def Stemming(sentence):
    stemmer = RSLPStemmer()
    phrase = []
    for word in sentence:
        phrase.append(stemmer.stem(word.lower()))
    return phrase

# %%
train_size = 0.8

logreg = LogisticRegression()
vectorizer = CountVectorizer(analyzer="word",tokenizer=None)    
pipe = Pipeline([ ('vect', vectorizer),('logreg', logreg)])

X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(
df.text, df.labels, train_size=train_size)

df_train = pd.DataFrame(X_train)
df_train['labels']=Y_train
df_train =df_train.reset_index(drop=True)

df_test = pd.DataFrame(X_test,index=None)
df_test['labels']=Y_test
df_test=df_test.reset_index(drop=True)
# Out:
# /home/leticia/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
df_train
# Out:
#                                                    text  labels
# 0                Someone shouldve invented this sooner.       1
# 1                              We loved the biscuits!!!       1
# 2     The service was a little slow , considering th...       0
# 3     On three different occasions I asked for well ...       0
# 4     They brought a fresh batch of fries and I was ...       0
# 5     I had heard good things about this place, but ...       1
# 6               The selection of food was not the best.       0
# 7     I have 2-3 bars on my cell phone when I am hom...       0
# 8                                          VERY funny!        1
# 9     At a time when it seems that film animation ha...       1
# 10                                 Very wind-resistant.       1
# 11                                   I love this thing!       1
# 12    !....THE OWNERS REALLY REALLY need to quit bei...       0
# 13                          Having trouble with volume.       0
# 14    Today is the second time I've been to their lu...       1
# 15    Bad day or not, I have a very low tolerance fo...       0
# 16              You can find better movies at youtube.        0
# 17                                Five star Plus, plus.       1
# 18    The building itself seems pretty neat; the bat...       0
# 19    You share General Loewenhielm's exquisite joy ...       1
# 20    This is so embarassing and also my ears hurt i...       0
# 21                     They dropped more than the ball.       0
# 22                 I did not expect this to be so good!       1
# 23    Well packaged, arrived on time, and works as i...       1
# 24             I got food poisoning here at the buffet.       0
# 25                    Dessert: Panna Cotta was amazing.       1
# 26    Not only did it only confirm that the film wou...       0
# 27                                    IT'S REALLY EASY.       1
# 28    The plot simply rumbles on like a machine, des...       0
# 29    this is the worst sushi i have ever eat beside...       0
# ...                                                 ...     ...
# 2370        Comfortable, Nice Range, Good Battery Life.       1
# 2371                             Service was fantastic.       1
# 2372                       The kids play area is NASTY!       0
# 2373  Still, it was the SETS that got a big "10" on ...       1
# 2374  Bad script, bad direction and horrible acting ...       0
# 2375  Don't make the same mistake that I did and ple...       0
# 2376            The story line is totally predictable.        0
# 2377                            The food was very good.       1
# 2378                                   It is not good.        0
# 2379  Very true to Shakespear, and a 'must' for all ...       1
# 2380          Not tasty and the texture was just nasty.       0
# 2381  Excellently produced by one of Sci-fi's best p...       1
# 2382          Not a pleasant voyage of self-discovery.        0
# 2383           much better than the hard plastic cases.       1
# 2384  It's one of the most boring Horror movies from...       0
# 2385                                      Again, lame.        0
# 2386          Works like a charm.. Works as advertised.       1
# 2387                 As I said above....PRETTY USELESS!       0
# 2388               Seriously flavorful delights, folks.       1
# 2389  Due to this happening on every call I was forc...       0
# 2390  The two main characters may be two of the most...       1
# 2391                               Omit watching this.        0
# 2392        It is a very well acted and done TV Movie.        1
# 2393              But it is entertaining, nonetheless.        1
# 2394                                 Poor Construction.       0
# 2395                    In a word, it is embarrassing.        0
# 2396  His losing his marbles so early in the proceed...       0
# 2397  Also, the phone doesn't seem to accept anythin...       0
# 2398  In the span of an hour, I had two people excla...       1
# 2399  Which is precisely why I am giving it such a b...       0
#
# [2400 rows x 2 columns]

# %%
df_test
# Out:
#                                                   text  labels
# 0                  I'll be looking for a new earpiece.       0
# 1             The restaurant atmosphere was exquisite.       1
# 2              I probably won't be back, to be honest.       0
# 3    If you stay in Vegas you must get breakfast he...       1
# 4                             Poorly contstruct hinge.       0
# 5    There is really nothing for me at postinos, ho...       0
# 6    Its well-designed and very sharp -- the blue i...       1
# 7    I have this phone and it is a thorn in my side...       0
# 8    The camera, although rated at an impressive 1....       0
# 9    The sangria was about half of a glass wine ful...       0
# 10            The commercials are the most misleading.       0
# 11   This place is hands-down one of the best place...       1
# 12   I don't think I've ever gone to a movie and di...       0
# 13   This movie is well-balanced with comedy and dr...       1
# 14   All the actors give a wonderful performance, e...       1
# 15                     So bad...well...it's just bad.        0
# 16                                      Bad Reception.       0
# 17          This scene is very strong and unpleasant.        0
# 18   Aside from it's terrible lead, this film has l...       0
# 19                                   Great bluetooth!.       1
# 20                                      Mediocre food.       0
# 21   For that price I can think of a few place I wo...       0
# 22   After all the rave reviews I couldn't wait to ...       0
# 23   The best example of how dumb the writing is wh...       0
# 24                                Perfect for the PS3.       1
# 25                                 BT50 battery junk!.       0
# 26                                      Was not happy.       0
# 27                  Don't make the same mistake I did.       0
# 28                      A great way to finish a great.       1
# 29                      Unfortunately it did not work.       0
# ..                                                 ...     ...
# 570  If you want to wait for mediocre food and down...       0
# 571                Always a pleasure dealing with him.       1
# 572  I totally and absolutely recommend this movie ...       1
# 573  Everything about this film is simply incredible.        1
# 574  It's so stupid to have to keep buying new char...       0
# 575                               Yes, it's that bad.        0
# 576                                     A great touch.       1
# 577  Maybe it's just their Vegetarian fare, but I'v...       0
# 578  The range is very decent, I've been able to ro...       1
# 579    I had the chicken Pho and it tasted very bland.       0
# 580                                        Brilliant!        1
# 581  It didn't make me scared, horrified, or make m...       0
# 582  It is indescribably the most annoying and idio...       0
# 583           If you want a real scare rent this one!        1
# 584  The character developments also lacked in depth.        0
# 585      The cocktails are all handmade and delicious.       1
# 586                                      Go watch it!        1
# 587                    This is an extraordinary film.        1
# 588  We waited for thirty minutes to be seated (alt...       0
# 589                              It was a great phone.       1
# 590  I've had this bluetoooth headset for some time...       0
# 591  The memories are murky but I can only say that...       1
# 592  I own a Jabra Earset and was very happy with i...       1
# 593               The replacement died in a few weeks.       0
# 594      I was bored throughout the whole damn thing.        0
# 595  Kris Kristoffersen is good in this movie and r...       1
# 596  Plus, it was well-paced and suited its relativ...       1
# 597  This is a VERY average phone with bad battery ...       0
# 598  The chicken dishes are OK, the beef is like sh...       0
# 599  i felt insulted and disrespected, how could yo...       0
#
# [600 rows x 2 columns]

# %%
def Learning(df_train):
    corpus_words = {}
    
    
    for index, row in df.iterrows():
        phrase = row['text']
        phrase = str(phrase)
        phrase = re.sub(r'[.|,|?|!]','', phrase)
        phrase = Tokenize(phrase)
        phrase = Stemming(phrase)
        class_name = row['labels']
        if class_name not in list(corpus_words.keys()):
            corpus_words[class_name] = {}
        for word in phrase:
            if word not in list(corpus_words[class_name].keys()):
                corpus_words[class_name][word] = 1
            else:
                corpus_words[class_name][word] += 1
    
    return corpus_words

# %%
data = Learning(df_train)

# %%
data
# Out:
# {0: {'a': 420,
#   'very': 97,
#   'slow-moving': 1,
#   'aimles': 1,
#   'movi': 107,
#   'about': 46,
#   'distressed': 1,
#   'drifting': 1,
#   'young': 1,
#   'man': 5,
#   'not': 260,
#   'sur': 11,
#   'who': 23,
#   'wa': 332,
#   'mor': 33,
#   'lost': 7,
#   '-': 42,
#   'the': 970,
#   'flat': 4,
#   'charact': 22,
#   'or': 52,
#   'audienc': 2,
#   'nearly': 2,
#   'half': 8,
#   'of': 314,
#   'whom': 2,
#   'walked': 5,
#   'out': 48,
#   'attempting': 1,
#   'artines': 1,
#   'with': 116,
#   'black': 8,
#   '&': 14,
#   'whit': 3,
#   'and': 460,
#   'clev': 2,
#   'cam': 22,
#   'angl': 2,
#   'disappointed': 29,
#   'becam': 2,
#   'even': 48,
#   'ridicul': 6,
#   'as': 90,
#   'acting': 27,
#   'po': 27,
#   'plot': 23,
#   'lin': 16,
#   'almost': 10,
#   'non-existent': 1,
#   'littl': 20,
#   'music': 7,
#   'anything': 11,
#   'to': 361,
#   'speak': 3,
#   'rest': 4,
#   'lack': 7,
#   'art': 2,
#   'charm': 2,
#   'meaning': 2,
#   'if': 64,
#   'it': 431,
#   "'s": 102,
#   'emptines': 1,
#   'work': 44,
#   'i': 546,
#   'gues': 8,
#   'becaus': 33,
#   'empty': 4,
#   'wasted': 9,
#   'two': 18,
#   'hour': 20,
#   'bit': 15,
#   'predictabl': 7,
#   'had': 69,
#   'som': 27,
#   'averag': 8,
#   'from': 54,
#   'main': 2,
#   'person': 3,
#   'low': 11,
#   'budget': 2,
#   'you': 116,
#   'clearly': 4,
#   'can': 35,
#   'see': 20,
#   'thil': 313,
#   'short': 5,
#   'film': 67,
#   'certainly': 6,
#   'pull': 4,
#   'no': 61,
#   'punch': 1,
#   'graphic': 2,
#   'is': 342,
#   'far': 13,
#   'best': 15,
#   'part': 8,
#   'gam': 4,
#   'today': 3,
#   'are': 88,
#   'crap': 11,
#   'flick': 5,
#   'doomed': 1,
#   'conception': 1,
#   'ide': 6,
#   'lam': 5,
#   'tak': 16,
#   'min': 3,
#   'mediocr': 11,
#   'pg-13': 2,
#   'mak': 38,
#   'complet': 3,
#   'non-sequel': 1,
#   'whil': 13,
#   'changing': 3,
#   'ton': 3,
#   'pg-rated': 1,
#   'family': 2,
#   "n't": 213,
#   'least': 10,
#   'interested': 2,
#   'only': 57,
#   'did': 65,
#   'confirm': 1,
#   'that': 184,
#   'would': 66,
#   'be': 94,
#   'unfunny': 2,
#   'generic': 2,
#   'but': 114,
#   'als': 30,
#   'managed': 3,
#   'giv': 12,
#   'away': 9,
#   'ent': 5,
#   ';': 10,
#   "'m": 32,
#   'exaggerating': 1,
#   'every': 12,
#   'moment': 2,
#   'point': 5,
#   'jok': 7,
#   'told': 4,
#   'in': 193,
#   'trail': 1,
#   'just': 66,
#   'funny': 3,
#   'talented': 1,
#   'carrell': 1,
#   'ca': 18,
#   'sav': 3,
#   'hi': 19,
#   'co-st': 1,
#   'do': 100,
#   'much': 34,
#   'bett': 25,
#   'peopl': 14,
#   'lik': 68,
#   'morgan': 1,
#   'freeman': 1,
#   'jonah': 1,
#   'hill': 1,
#   'ed': 2,
#   'helm': 1,
#   'story': 16,
#   'itself': 5,
#   'lazy': 2,
#   'real': 17,
#   'effect': 5,
#   'presenc': 1,
#   'all': 75,
#   'animal': 1,
#   'integration': 1,
#   'thos': 9,
#   'int': 17,
#   'scen': 20,
#   'worst': 38,
#   'most': 18,
#   'obvi': 1,
#   'blue/green-screen': 1,
#   "'ve": 34,
#   'ev': 46,
#   'seen': 17,
#   'whatev': 5,
#   'cost': 8,
#   'th': 27,
#   'so': 78,
#   'translat': 1,
#   'quality': 28,
#   'for': 177,
#   'on': 111,
#   'negativ': 3,
#   'insipid': 1,
#   'enough': 23,
#   'caus': 3,
#   'regret': 1,
#   'anoth': 14,
#   '2': 21,
#   'lif': 11,
#   'front': 5,
#   'screen': 8,
#   'long': 18,
#   'whiny': 2,
#   'pointles': 2,
#   'recommend': 16,
#   'waiting': 7,
#   'futur': 1,
#   'effort': 2,
#   'let': 9,
#   'one': 71,
#   'go': 35,
#   'totally': 13,
#   'annoying': 6,
#   'voic': 4,
#   'me': 48,
#   'feeling': 7,
#   'fingernail': 1,
#   'chalkboard': 1,
#   'ther': 77,
#   'unnecessary': 1,
#   'train/roll': 1,
#   'coast': 1,
#   'absolutely': 9,
#   'warmth': 1,
#   'thes': 17,
#   'grat': 1,
#   'my': 125,
#   'nerv': 1,
#   'performanc': 5,
#   'improved': 1,
#   'by': 38,
#   'improvisation': 1,
#   'act': 12,
#   'now': 21,
#   'hav': 94,
#   'twic': 2,
#   'worry': 1,
#   ':': 20,
#   'wheth': 4,
#   'they': 52,
#   "'re": 8,
#   'delivering': 1,
#   'well': 23,
#   'any': 28,
#   'good': 52,
#   'quit': 12,
#   'honestly': 3,
#   'often': 3,
#   'dialog': 12,
#   'doe': 44,
#   'really': 47,
#   'follow': 3,
#   'fit': 8,
#   'surrounding': 1,
#   'crackl': 1,
#   'an': 42,
#   'unpredictabl': 1,
#   'youthful': 1,
#   'energy': 3,
#   'found': 10,
#   'hard': 11,
#   'concentrat': 1,
#   'meand': 1,
#   'badly': 2,
#   'say': 19,
#   'worth': 11,
#   'your': 51,
#   'tim': 76,
#   'though': 6,
#   'glad': 3,
#   'pretenti': 4,
#   'piec': 23,
#   's***': 1,
#   'planned': 1,
#   'dodg': 1,
#   'stratu': 1,
#   'big': 12,
#   'shot': 5,
#   'gon': 6,
#   'na': 3,
#   'help': 2,
#   'restrained': 1,
#   '``': 34,
#   'busines': 5,
#   "''": 33,
#   'quã©bec': 1,
#   'probl': 19,
#   'script': 21,
#   'horrend': 1,
#   'nothing': 21,
#   'believabl': 1,
#   'at': 87,
#   'suspens': 4,
#   'frustration': 2,
#   'how': 40,
#   'retarded': 1,
#   'girl': 6,
#   'wer': 54,
#   'frankly': 2,
#   'aft': 36,
#   'cotton': 1,
#   'club': 1,
#   'unfaithful': 1,
#   'kind': 12,
#   'embarrassing': 5,
#   'watch': 8,
#   'lan': 2,
#   'ger': 1,
#   'bad': 96,
#   'extremely': 9,
#   'shallow': 1,
#   'insinc': 1,
#   'too': 39,
#   'chick': 3,
#   'politically': 1,
#   'correct': 2,
#   'disappointing': 12,
#   'lov': 7,
#   'nev': 37,
#   'her': 53,
#   'lousy': 3,
#   'wish': 3,
#   'could': 46,
#   'bring': 6,
#   'back': 48,
#   'directing': 7,
#   'cinematography': 1,
#   'boring': 9,
#   'sometim': 4,
#   'myself': 4,
#   'occupied': 2,
#   'peaking': 1,
#   'pap': 3,
#   'instead': 3,
#   'watching': 11,
#   '(': 42,
#   'happened': 6,
#   'during': 4,
#   'columb': 1,
#   'befor': 15,
#   ')': 45,
#   'look': 26,
#   'se': 7,
#   'oh-so-matur': 1,
#   'neighbour-girl': 1,
#   'misplac': 1,
#   'generally': 2,
#   'weak': 9,
#   'than': 33,
#   'episod': 2,
#   'then': 28,
#   'wher': 11,
#   'debated': 1,
#   'sack': 1,
#   'trumpet': 1,
#   'falsely': 1,
#   'accused': 1,
#   'murd': 1,
#   'pur': 2,
#   'horr': 5,
#   'stupid': 17,
#   'thought': 9,
#   'playing': 2,
#   'villain': 1,
#   'rent': 3,
#   'michael': 1,
#   'ironsid': 1,
#   'howev': 12,
#   'up': 40,
#   'fact': 4,
#   'overall': 6,
#   'tremendously': 1,
#   'chemistry': 2,
#   'between': 10,
#   'ben': 1,
#   'affleck': 1,
#   'sandr': 2,
#   'bullock': 2,
#   'understand': 8,
#   'why': 8,
#   'he': 41,
#   'consid': 2,
#   'leaving': 1,
#   'wife-to-b': 1,
#   'supposedly': 3,
#   'knocked': 1,
#   'sever': 6,
#   'need': 7,
#   'excruciatingly': 1,
#   'slow': 18,
#   'moving': 3,
#   'remak': 3,
#   'friend': 6,
#   'wedding': 1,
#   'great': 10,
#   'disappointment': 11,
#   'believ': 7,
#   'agreed': 1,
#   'stand': 2,
#   'fe': 3,
#   'losing': 2,
#   'iq': 2,
#   'nobody': 3,
#   'network': 3,
#   'aired': 1,
#   'dribbl': 1,
#   'watched': 8,
#   'putting': 3,
#   'imdb': 1,
#   'rating': 6,
#   '1': 12,
#   'awful': 20,
#   'get': 38,
#   'numb': 4,
#   'cas': 13,
#   'such': 9,
#   'saw': 3,
#   'mirrormask': 1,
#   'last': 13,
#   'night': 8,
#   'unsatisfactory': 2,
#   'experienc': 14,
#   'unfortunately': 12,
#   'inexperienc': 1,
#   'direction': 4,
#   'meant': 1,
#   'passed': 3,
#   'way': 27,
#   'dramatic': 1,
#   'tension': 2,
#   'conflict': 2,
#   'centr': 1,
#   'them': 2,
#   'handled': 2,
#   'ineptly': 1,
#   'stereotypically': 1,
#   'depth': 4,
#   'imagination': 4,
#   'pretty': 14,
#   'pictur': 11,
#   'world': 3,
#   'flawed': 3,
#   'cor': 2,
#   'wast': 32,
#   'following': 1,
#   'bunch': 2,
#   'high': 6,
#   'school': 2,
#   'whin': 2,
#   'cry': 1,
#   'relat': 1,
#   'hell': 4,
#   'barely': 9,
#   'disast': 2,
#   'editing': 3,
#   'confus': 1,
#   'incredibly': 3,
#   'fish': 4,
#   'mad': 26,
#   'underwat': 1,
#   'repeated': 1,
#   'thousand': 1,
#   'truly': 3,
#   'terribl': 31,
#   'writing': 10,
#   'wors': 13,
#   'possibl': 6,
#   'redeemed': 1,
#   'mst3k': 1,
#   'fodd': 1,
#   'paid': 4,
#   'whatsoev': 6,
#   'again': 27,
#   'horribl': 20,
#   'lifeoh': 1,
#   'gosh': 1,
#   'walk': 1,
#   'theatr': 1,
#   'few': 18,
#   'minut': 32,
#   'relief': 1,
#   'hat': 9,
#   'yeah': 3,
#   'sucked': 11,
#   'storylin': 4,
#   'pillow': 1,
#   'girlfriend/boyfriend': 1,
#   'keep': 7,
#   'through': 5,
#   'think': 23,
#   'disliked': 2,
#   'thing': 35,
#   'ticket': 1,
#   'fiv': 3,
#   'doll': 3,
#   "'d": 13,
#   '$': 17,
#   '750': 1,
#   'identifi': 1,
#   'cardboard': 2,
#   'cutout': 1,
#   'stereotyp': 2,
#   'predictably': 2,
#   'reverse-stereotyp': 1,
#   'actorsan': 1,
#   'ugly': 2,
#   'cartoon': 1,
#   'crafted': 1,
#   'paul': 2,
#   'haggil': 1,
#   'handl': 1,
#   'bold': 1,
#   'strok': 1,
#   'storytelling': 1,
#   'painted': 1,
#   'crayom': 1,
#   'crash': 1,
#   'depressing': 2,
#   'provok': 1,
#   'emotion': 1,
#   'teach': 1,
#   'already': 1,
#   'know': 19,
#   'racism': 1,
#   'prejud': 1,
#   'brain': 2,
#   'will': 38,
#   'attempt': 4,
#   'shut-down': 1,
#   'prim': 2,
#   'impuls': 1,
#   'self-preservation': 1,
#   'left': 8,
#   'shattered': 1,
#   "'film": 1,
#   "'": 6,
#   'took': 10,
#   'fully': 2,
#   'recov': 1,
#   'joim': 1,
#   'reveng': 1,
#   'boogeyman': 1,
#   'zombi': 2,
#   'hellish': 1,
#   'trinity': 1,
#   'mean': 5,
#   'distinction': 1,
#   'ha': 31,
#   'redeeming': 2,
#   'featur': 4,
#   'everything': 12,
#   'appalling': 3,
#   'artles': 1,
#   'camera-work': 1,
#   'endlessly': 1,
#   'present': 1,
#   'us': 17,
#   'ugliest': 1,
#   'setting': 4,
#   'imaginabl': 1,
#   'ie': 1,
#   'beyond': 5,
#   'isâ…w': 1,
#   'kid': 5,
#   'lead': 3,
#   'charisma-fre': 1,
#   'utterly': 4,
#   'without': 5,
#   'merit': 1,
#   'level': 3,
#   'akin': 1,
#   'tortur': 4,
#   "'ll": 11,
#   'â–': 2,
#   'mayb': 5,
#   'reasonabl': 1,
#   'explanation': 2,
#   'atrocity': 1,
#   'pleasant': 2,
#   'voyag': 1,
#   'self-discovery': 1,
#   'highly': 4,
#   'unrecommended': 1,
#   'premis': 3,
#   'sound': 17,
#   'ye': 13,
#   'suffered': 1,
#   'needed': 4,
#   'many': 12,
#   'clos': 3,
#   'oth': 25,
#   'seemed': 5,
#   'drag': 3,
#   'hero': 1,
#   'freedom': 2,
#   'definitely': 10,
#   'below': 4,
#   'anyon': 13,
#   'enjoy': 5,
#   'self-indulgent': 1,
#   'junk': 9,
#   'probably': 16,
#   'been': 25,
#   'direc': 5,
#   'spent': 3,
#   'showcasing': 1,
#   'own': 6,
#   'which': 31,
#   'noteworthy': 1,
#   'when': 35,
#   'got': 24,
#   'punched': 1,
#   'fac': 6,
#   'gallon': 1,
#   'blood': 1,
#   'spew': 1,
#   'forth': 2,
#   'soon': 9,
#   'ironically': 1,
#   'mostly': 3,
#   'find': 9,
#   'total': 4,
#   'pandering': 1,
#   'sabotag': 1,
#   'henc': 1,
#   'whol': 8,
#   'certain': 2,
#   'simply': 8,
#   'rumbl': 1,
#   'machin': 2,
#   'desperately': 1,
#   'depending': 1,
#   'addition': 2,
#   'new': 13,
#   'usual': 1,
#   'hitchcock': 1,
#   'logic': 1,
#   'flaw': 4,
#   'mish': 1,
#   'uninteresting': 2,
#   'chilly': 2,
#   'unremarkabl': 1,
#   'auth': 1,
#   'living/working': 1,
#   'abstrus': 1,
#   'cultur': 1,
#   'reenactment': 1,
#   'hold': 6,
#   'attention': 2,
#   'emotionally': 1,
#   'adrift': 1,
#   'stagy': 1,
#   'sit': 3,
#   'being': 20,
#   'soldi': 1,
#   'singing': 2,
#   'song': 3,
#   'masculinity': 1,
#   'pledg': 1,
#   'themselv': 2,
#   'hairsplitting': 1,
#   'purity': 1,
#   'admiration': 1,
#   'sword': 1,
#   'etc': 3,
#   'bor': 3,
#   'kill': 4,
#   'momentum': 1,
#   'quick': 2,
#   'els': 7,
#   'schrad': 1,
#   'resum': 1,
#   'full': 6,
#   'amateurish': 1,
#   'recently': 4,
#   'dvd': 2,
#   'completely': 10,
#   'struck': 2,
#   'contained': 2,
#   'hol': 6,
#   'inconsistenci': 1,
#   'lot': 12,
#   'horrid': 1,
#   'dancing': 1,
#   'realistic': 1,
#   'she': 13,
#   'gotten': 3,
#   'ballet': 1,
#   'repertory': 1,
#   'pathetic': 5,
#   'development': 1,
#   'lacked': 5,
#   'woa': 1,
#   'talk': 14,
#   'sappiest': 1,
#   'what': 39,
#   'unwatchabl': 1,
#   'tell': 6,
#   'talent': 2,
#   'gav': 5,
#   'action': 6,
#   'check': 4,
#   'filmography': 1,
#   'chanc': 1,
#   'tv': 2,
#   'regrettably': 1,
#   'fail': 10,
#   'visual': 2,
#   'interest': 2,
#   'dram': 3,
#   'expression': 1,
#   'celebration': 1,
#   'patriotism': 1,
#   'underlin': 1,
#   'narrativ': 2,
#   'actres': 2,
#   'used': 14,
#   'jun': 1,
#   'allison': 1,
#   'plain': 5,
#   'cinematography-if': 1,
#   'called': 1,
#   'that-sucked': 1,
#   'soundtrack': 1,
#   'concert': 1,
#   'sequenc': 2,
#   'cheap': 14,
#   'trash': 5,
#   'considering': 4,
#   'ridiculousnes': 1,
#   'angry': 2,
#   'trying': 7,
#   'turn': 7,
#   'day': 13,
#   'disturbing': 1,
#   'memori': 1,
#   'succeeded': 1,
#   'forced': 3,
#   'pi**ed': 1,
#   'off': 27,
#   'started': 11,
#   'jerky': 2,
#   'camerawork': 2,
#   'theat': 1,
#   'going': 22,
#   'sick': 7,
#   'summary': 2,
#   'witticism': 1,
#   'witty': 1,
#   'said': 11,
#   'billy': 1,
#   'bob': 3,
#   'ris': 1,
#   'abov': 4,
#   '10': 9,
#   'literally': 6,
#   'vomited': 2,
#   'translating': 1,
#   'living': 2,
#   'first': 26,
#   '5-ye': 2,
#   'working': 4,
#   'offensiv': 2,
#   'intelligenc': 4,
#   'someon': 5,
#   'striv': 1,
#   'greatnes': 1,
#   'poetry': 1,
#   'deliv': 2,
#   'muddled': 1,
#   'disparat': 1,
#   'review': 10,
#   'accurately': 1,
#   'defined': 1,
#   'intelligent': 2,
#   'masterful': 1,
#   'obviously': 5,
#   'try': 7,
#   'sens': 5,
#   'pitiful': 3,
#   'our': 22,
#   'human': 5,
#   'natur': 1,
#   'tolerat': 1,
#   'politic': 1,
#   'incorrectnes': 1,
#   'artistic': 1,
#   'suspension': 1,
#   'disbelief': 2,
#   'slavic': 1,
#   'femal': 1,
#   'underneath': 1,
#   'malt': 1,
#   'dry': 5,
#   'barren': 1,
#   'hockey': 1,
#   'defensemen': 1,
#   '5': 8,
#   'old': 15,
#   'goali': 1,
#   'diving': 1,
#   'feet': 2,
#   'wid': 1,
#   'net': 1,
#   'call': 20,
#   'particul': 4,
#   'relationship': 2,
#   'bakery': 2,
#   'assistant': 2,
#   'waitres': 4,
#   'superfic': 1,
#   'play': 10,
#   'rath': 7,
#   "'stagey": 1,
#   'stag': 1,
#   'farc': 1,
#   'pyromaniac': 1,
#   'waylaid': 1,
#   'bored': 4,
#   'car': 16,
#   'next': 9,
#   'switched': 1,
#   'pay': 7,
#   'laugh': 1,
#   'smil': 1,
#   'onc': 6,
#   'yawn': 1,
#   'storm': 1,
#   'troop': 1,
#   'list': 3,
#   'wonderfully': 1,
#   'guy': 4,
#   'potted': 1,
#   'plant': 1,
#   'right': 12,
#   'shameful': 1,
#   'memorabl': 1,
#   'forgetting': 2,
#   'felt': 10,
#   'ireland': 1,
#   'scared': 2,
#   'horrified': 1,
#   'sympathetic': 1,
#   'toward': 4,
#   'movement': 1,
#   'sam': 14,
#   'supposed': 2,
#   'twist': 2,
#   'shed': 1,
#   'light': 4,
#   'situation': 1,
#   'should': 17,
#   'leav': 5,
#   'shelf': 1,
#   'ov': 19,
#   'top': 6,
#   'unrealistic': 1,
#   'throughout': 4,
#   '90': 5,
#   'utt': 2,
#   'looked': 4,
#   '70000': 1,
#   'lucy': 1,
#   'bell': 2,
#   'sink': 1,
#   'slack': 1,
#   'excus': 4,
#   'actiom': 1,
#   'god': 3,
#   'cov': 4,
#   'old-fashioned': 1,
#   'tuneful': 1,
#   "'cov": 2,
#   'rit': 1,
#   'hayworth': 1,
#   'put': 8,
#   'pedest': 1,
#   'exampl': 3,
#   'hollywood': 1,
#   'exploit': 1,
#   'women': 2,
#   'financ': 1,
#   'gain': 1,
#   'seriously': 7,
#   'am': 19,
#   'fan': 3,
#   'tick': 2,
#   '3': 9,
#   '4': 4,
#   'building': 3,
#   'coupl': 5,
#   'locatiom': 1,
#   'hummh': 1,
#   'blew': 2,
#   'we': 65,
#   'chosen': 1,
#   'tortured': 1,
#   'disgusting': 4,
#   'blatant': 1,
#   'american': 1,
#   'propagand': 1,
#   'show': 16,
#   'americ': 1,
#   'hatred': 1,
#   'clichã©': 3,
#   'admitted': 1,
#   'elsewh': 6,
#   'everyon': 7,
#   'involved': 5,
#   'must': 6,
#   'return': 11,
#   'pil': 2,
#   'garbag': 6,
#   'round': 1,
#   'valu': 4,
#   'admim': 1,
#   'set': 5,
#   'plac': 60,
#   'thunderbird': 1,
#   'use': 25,
#   'slow-motion': 1,
#   'needlessly': 1,
#   'repeat': 1,
#   'backed': 1,
#   'word': 8,
#   'continuity': 2,
#   'thrown': 3,
#   'reason': 6,
#   'vehicl': 2,
#   'corn': 1,
#   'flak': 1,
#   'box': 2,
#   'director': 1,
#   'styl': 5,
#   'bordered': 1,
#   'stupidity': 1,
#   'oh': 5,
#   'especially': 6,
#   'st': 14,
#   'second': 6,
#   'proud': 1,
#   'filmmak': 1,
#   'nor': 1,
#   'hid': 1,
#   'head': 3,
#   'sand': 1,
#   'amount': 2,
#   'money': 28,
#   'monument': 1,
#   'fre': 2,
#   'bought': 12,
#   'still': 18,
#   'turned': 4,
#   'halfway': 1,
#   'embarrassed': 1,
#   'howell': 1,
#   '1/10': 1,
#   '0/10': 2,
#   '--': 9,
#   'profess': 1,
#   'debbi': 1,
#   'rochon': 1,
#   'perhap': 4,
#   'contributory': 1,
#   'form': 2,
#   'chimp-lik': 1,
#   'tolerabl': 1,
#   'simplifying': 1,
#   'sak': 2,
#   'brevity': 1,
#   'fulfilling': 1,
#   'convoluted': 1,
#   'convinc': 1,
#   'weird': 3,
#   'questioning': 1,
#   'glanc': 1,
#   'girlfriend': 2,
#   'seeing': 2,
#   'both': 13,
#   'hated': 4,
#   'bel': 1,
#   'lugos': 1,
#   'extran': 1,
#   'intoning': 1,
#   'odd': 2,
#   'decidely': 1,
#   'wooden': 3,
#   'period': 2,
#   'univers': 1,
#   'b': 1,
#   'wow': 1,
#   'frightening': 2,
#   'comprehensibl': 1,
#   'hang': 1,
#   'togeth': 4,
#   'camp': 1,
#   'expecting': 1,
#   'osc': 2,
#   'mater': 2,
#   'particularly': 2,
#   ...},
#  1: {'the': 1025,
#   'best': 63,
#   'scen': 14,
#   'in': 205,
#   'movi': 102,
#   'wa': 261,
#   'when': 36,
#   'gerard': 1,
#   'is': 418,
#   'trying': 2,
#   'to': 306,
#   'find': 12,
#   'a': 465,
#   'song': 7,
#   'that': 135,
#   'keep': 5,
#   'running': 3,
#   'through': 8,
#   'hi': 29,
#   'head': 2,
#   'saw': 9,
#   'today': 6,
#   'and': 669,
#   'thought': 11,
#   'it': 410,
#   'good': 174,
#   'effort': 2,
#   'messag': 2,
#   'for': 159,
#   'kid': 6,
#   'loved': 21,
#   'casting': 5,
#   'of': 308,
#   'jimmy': 2,
#   'buffet': 9,
#   'as': 86,
#   'scienc': 1,
#   'teach': 1,
#   'thos': 10,
#   'baby': 2,
#   'owl': 1,
#   'wer': 54,
#   'adorabl': 4,
#   'showed': 3,
#   'lot': 19,
#   'flor': 1,
#   'at': 47,
#   "'s": 142,
#   'mad': 34,
#   'look': 19,
#   'very': 146,
#   'appealing': 2,
#   'muppet': 1,
#   'so': 90,
#   'hilari': 5,
#   'cool': 17,
#   'thil': 328,
#   '``': 35,
#   'right': 21,
#   'on': 108,
#   'cas': 25,
#   "''": 28,
#   'deliv': 3,
#   'everything': 22,
#   'almost': 4,
#   'your': 31,
#   'fac': 6,
#   'review': 7,
#   'long': 13,
#   'overdu': 1,
#   'sinc': 12,
#   'i': 480,
#   'consid': 4,
#   'tal': 4,
#   'two': 17,
#   'sist': 4,
#   'be': 65,
#   'singl': 4,
#   'greatest': 3,
#   'film': 116,
#   'ev': 30,
#   "'ll": 12,
#   'put': 4,
#   'gem': 4,
#   'up': 33,
#   'against': 2,
#   'any': 25,
#   'term': 2,
#   'screenplay': 1,
#   'cinematography': 7,
#   'acting': 15,
#   'post-production': 1,
#   'editing': 4,
#   'directing': 2,
#   'or': 30,
#   'oth': 31,
#   'aspect': 2,
#   'film-making': 2,
#   'practically': 1,
#   'perfect': 17,
#   'all': 69,
#   'th': 23,
#   'â–': 3,
#   'tru': 4,
#   'masterpiec': 4,
#   'sea': 3,
#   'faux': 3,
#   'structur': 1,
#   'easily': 4,
#   'most': 22,
#   'tightly': 1,
#   'constructed': 1,
#   'history': 6,
#   'cinem': 8,
#   'can': 34,
#   'think': 24,
#   'no': 21,
#   'wher': 8,
#   'something': 6,
#   'vitally': 1,
#   'important': 5,
#   'occur': 1,
#   'every': 23,
#   'minut': 5,
#   'word': 3,
#   'content': 1,
#   'level': 4,
#   'enough': 13,
#   'fill': 1,
#   'dozen': 1,
#   'how': 17,
#   'anyon': 10,
#   'mind': 3,
#   'ask': 6,
#   'anything': 4,
#   'mor': 34,
#   'from': 49,
#   'than': 34,
#   'quit': 15,
#   'simply': 7,
#   'highest': 2,
#   'superlativ': 1,
#   'form': 4,
#   'imaginabl': 1,
#   'ye': 29,
#   'doe': 21,
#   'requ': 1,
#   'rath': 6,
#   'significant': 3,
#   'amount': 6,
#   'puzzle-solving': 1,
#   'but': 86,
#   'piec': 6,
#   'fit': 17,
#   'togeth': 6,
#   'creat': 3,
#   'beautiful': 17,
#   'pictur': 7,
#   'numb': 2,
#   'one': 76,
#   'gam': 10,
#   'seri': 6,
#   'deserv': 3,
#   'strong': 7,
#   'lov': 61,
#   'an': 63,
#   'insan': 1,
#   'ther': 34,
#   'are': 105,
#   'massiv': 4,
#   'unlockabl': 1,
#   'charact': 36,
#   'just': 54,
#   'wast': 1,
#   'money': 3,
#   'kind': 7,
#   'wasted': 1,
#   'properly': 1,
#   'actually': 12,
#   'graphic': 3,
#   'tim': 58,
#   'they': 54,
#   'say': 21,
#   'fun': 9,
#   'aye': 1,
#   'rock': 4,
#   'buy': 6,
#   'play': 14,
#   'enjoy': 7,
#   'pur': 1,
#   'brillianc': 3,
#   'succeed': 1,
#   'despit': 3,
#   'perhap': 4,
#   'becaus': 24,
#   'obviously': 3,
#   'meagr': 1,
#   'budget': 3,
#   "'m": 20,
#   'glad': 6,
#   'did': 26,
#   "n't": 63,
#   'go': 28,
#   'obvi': 1,
#   'choic': 6,
#   'less': 1,
#   'certainly': 5,
#   'would': 28,
#   'hav': 94,
#   'addition': 2,
#   'having': 5,
#   'lovely': 6,
#   'written': 4,
#   'french': 2,
#   'cancan': 1,
#   'als': 44,
#   'boast': 1,
#   'cutest': 1,
#   'leading': 1,
#   'ladi': 3,
#   'grac': 3,
#   'screen': 12,
#   'hard': 4,
#   'not': 61,
#   'fall': 4,
#   'head-over-heel': 1,
#   'with': 157,
#   'girl': 2,
#   'excellent': 51,
#   'cast': 14,
#   'story': 12,
#   'lin': 7,
#   'performanc': 17,
#   'totally': 6,
#   'believabl': 5,
#   'ann': 4,
#   'hech': 1,
#   'utterly': 1,
#   'convincing': 3,
#   'sam': 7,
#   'shepard': 1,
#   'portray': 7,
#   'gung': 1,
#   'ho': 1,
#   'marin': 1,
#   'sobering': 1,
#   'sat': 4,
#   'riveted': 1,
#   'tv': 7,
#   'giv': 17,
#   'resounding': 1,
#   '9': 1,
#   'out': 40,
#   '10': 14,
#   'do': 35,
#   'tom': 6,
#   'hank': 1,
#   'act': 19,
#   'enjoyed': 14,
#   'reading': 2,
#   'book': 4,
#   'my': 126,
#   'children': 3,
#   'littl': 15,
#   'som': 27,
#   'generally': 3,
#   'great': 199,
#   'thing': 18,
#   'suspens': 3,
#   'build': 2,
#   '&': 14,
#   'cros': 1,
#   'g': 1,
#   'pg': 1,
#   'especially': 10,
#   'liked': 13,
#   'non-clich': 1,
#   'parent': 2,
#   ';': 15,
#   'could': 25,
#   'predict': 1,
#   'dialog': 5,
#   'verbatim': 1,
#   'writing': 4,
#   'bett': 28,
#   'selectiom': 3,
#   'if': 39,
#   'you': 105,
#   'want': 13,
#   'gros': 1,
#   'chill': 1,
#   'alexand': 2,
#   'nevsky': 1,
#   'he': 37,
#   'amazing': 29,
#   'artist': 2,
#   'whoev': 1,
#   'lived': 1,
#   'first': 19,
#   "'ve": 30,
#   'given': 4,
#   'needed': 3,
#   'word-of-mouth': 1,
#   'promot': 1,
#   'overall': 10,
#   'interesting': 14,
#   'thought-provoking': 1,
#   'plu': 7,
#   'well-paced': 1,
#   'suited': 1,
#   'relatively': 1,
#   'short': 8,
#   'run': 4,
#   'gav': 5,
#   'wind': 3,
#   'lion': 3,
#   'well': 62,
#   'superbly': 2,
#   'acted': 3,
#   'classic': 7,
#   'turned': 1,
#   'pretty': 27,
#   'decent': 6,
#   'far': 17,
#   'b-list': 1,
#   'horror/susp': 1,
#   'definitely': 22,
#   'worth': 16,
#   'checking': 3,
#   'mann': 1,
#   'heaven': 2,
#   'terrific': 6,
#   'both': 23,
#   'predictabl': 3,
#   'unpredictabl': 1,
#   'often': 2,
#   'funny': 17,
#   'occasionally': 4,
#   'touching': 3,
#   'evaluat': 1,
#   'liv': 2,
#   'going': 11,
#   'veteran': 1,
#   'nostalg': 1,
#   'trip': 4,
#   'ursul': 1,
#   'burton': 1,
#   'nun': 1,
#   'making': 3,
#   'num': 1,
#   'church': 2,
#   'looking': 6,
#   'music': 12,
#   '(': 52,
#   'including': 4,
#   'shirley': 1,
#   'jon': 1,
#   'rendition': 1,
#   'way': 20,
#   'tonight': 1,
#   ')': 58,
#   'uplifting': 2,
#   'ending': 9,
#   'try': 8,
#   'will': 36,
#   'disappointed': 6,
#   'only': 22,
#   'really': 56,
#   'watching': 11,
#   'scenery': 3,
#   'hous': 6,
#   'fresh': 12,
#   'bold': 1,
#   'help': 3,
#   'along': 3,
#   'mayb': 2,
#   'idiot-savant': 1,
#   'been': 25,
#   'played': 10,
#   'real': 15,
#   'joy': 7,
#   'watch': 11,
#   'applaus': 1,
#   'should': 6,
#   'prelud': 1,
#   'howev': 8,
#   'by': 40,
#   'direc': 9,
#   'had': 71,
#   'edg': 3,
#   'seat': 1,
#   'somewhat': 3,
#   'afraid': 2,
#   'car': 17,
#   'end': 11,
#   'night': 10,
#   'nic': 50,
#   'too': 16,
#   "'d": 11,
#   'advis': 2,
#   'see': 23,
#   'brilliant': 7,
#   '10/10': 3,
#   'much': 16,
#   'rocked': 1,
#   'world': 5,
#   'must': 10,
#   'soc': 1,
#   'physic': 1,
#   'outlet': 2,
#   'cult': 4,
#   'viewing': 2,
#   'sharing': 1,
#   'treat': 3,
#   'anthony': 1,
#   'quinn': 2,
#   'playing': 6,
#   'crazy': 3,
#   'hors': 1,
#   'still': 21,
#   'lik': 59,
#   'empowerment': 1,
#   'women': 1,
#   'ms': 1,
#   'garb': 1,
#   'who': 28,
#   'off': 11,
#   'bat': 2,
#   'her': 52,
#   'talent': 1,
#   'carry': 2,
#   'ov': 17,
#   'silent': 5,
#   'era': 3,
#   'wanted': 4,
#   'work': 65,
#   'netflix': 1,
#   'se': 8,
#   'stocking': 1,
#   'renowned': 1,
#   'screenwrit': 2,
#   'franc': 1,
#   'marion': 1,
#   'ha': 59,
#   'missed': 2,
#   'step': 2,
#   'sound': 34,
#   'received': 6,
#   'quality': 37,
#   'age': 3,
#   'john': 6,
#   'wayn': 2,
#   'incredibl': 12,
#   'job': 16,
#   'being': 14,
#   'young': 4,
#   'industry': 2,
#   'presenc': 1,
#   'shined': 1,
#   'even': 29,
#   'though': 12,
#   'seni': 1,
#   'him': 7,
#   'old': 5,
#   'jami': 2,
#   'foxx': 1,
#   'absolutely': 12,
#   'ray': 4,
#   'charl': 4,
#   'gen': 2,
#   'owm': 1,
#   'spacek': 1,
#   'owned': 4,
#   'coal': 1,
#   'min': 3,
#   'daught': 3,
#   'quaid': 1,
#   'ball': 1,
#   'fir': 3,
#   'fact': 8,
#   'rememb': 2,
#   'part': 14,
#   'man': 10,
#   'himself': 1,
#   'legendary': 1,
#   "'": 7,
#   'lif': 14,
#   'provided': 3,
#   'biographic': 1,
#   'mater': 1,
#   'which': 27,
#   'goe': 2,
#   'beyond': 2,
#   'anoth': 7,
#   'about': 39,
#   'musician': 1,
#   'hitchcock': 5,
#   'secondly': 1,
#   'perfected': 1,
#   'thrill': 5,
#   'chas': 1,
#   'watched': 4,
#   '80': 2,
#   'fascinated': 1,
#   'dancing': 2,
#   'intentiom': 1,
#   'then': 6,
#   'might': 2,
#   'mast': 3,
#   'them': 3,
#   '--': 13,
#   'least': 5,
#   'would-b': 1,
#   'underton': 1,
#   'fifti': 1,
#   'existent': 1,
#   'world-wearines': 1,
#   'aer': 3,
#   'ought': 1,
#   'thrilled': 3,
#   'sens': 1,
#   'imagination': 1,
#   'deeply': 2,
#   'yet': 8,
#   '***spoilers***': 1,
#   'whatev': 2,
#   'els': 2,
#   'ca': 7,
#   'said': 6,
#   'surfac': 1,
#   'crafted': 1,
#   'stunning': 3,
#   'fx': 2,
#   'nothing': 5,
#   'state-of-the-art': 1,
#   'conceptually': 1,
#   'show': 8,
#   'bit': 5,
#   'everything-': 1,
#   'everybody': 1,
#   'fantasy': 1,
#   'and/': 1,
#   'fam': 7,
#   'sour': 2,
#   'struck': 1,
#   'acting-wis': 1,
#   'eith': 3,
#   'surprisingly': 2,
#   'solid': 6,
#   'considered': 1,
#   'don': 9,
#   'thank': 4,
#   'released': 2,
#   'mexican': 4,
#   'les': 6,
#   'understood': 1,
#   'themselv': 3,
#   'matt': 2,
#   'identified': 1,
#   'felt': 5,
#   'rank': 3,
#   'highly': 19,
#   'noir-crime-dram': 1,
#   'belm': 1,
#   'vent': 1,
#   'attention': 2,
#   'complex': 2,
#   'psychologic': 2,
#   'detailing': 1,
#   'loyalty': 1,
#   'treachery': 1,
#   'hop': 6,
#   'tremend': 3,
#   'dram': 6,
#   'melvill': 1,
#   'truly': 8,
#   'tak': 9,
#   'journey': 3,
#   'eye': 5,
#   'soul': 2,
#   'child': 5,
#   'black': 10,
#   'wat': 2,
#   'manag': 3,
#   'completely': 4,
#   'transcend': 1,
#   'limitatiom': 1,
#   'indi': 1,
#   'flick': 2,
#   'continually': 1,
#   'subverting': 1,
#   'expectatiom': 2,
#   'emerg': 1,
#   'intens': 1,
#   'experienc': 17,
#   'gripping': 2,
#   'crocdodil': 1,
#   'extremely': 3,
#   'indeed': 4,
#   'websit': 2,
#   'believed': 1,
#   'used': 13,
#   'croc': 1,
#   'swamp': 1,
#   'location': 2,
#   'fabul': 3,
#   'thoroughly': 3,
#   'christoph': 1,
#   'eccleston': 1,
#   'took': 2,
#   'control': 3,
#   'tardil': 1,
#   'continuation': 1,
#   'plac': 63,
#   'final': 2,
#   'possibly': 3,
#   'trilogy': 3,
#   'kieslowsk': 1,
#   'nev': 14,
#   'ceas': 2,
#   'amaz': 1,
#   'me': 23,
#   'favourit': 3,
#   'talented': 2,
#   'use': 26,
#   'colour': 1,
#   'flag': 1,
#   'thre': 6,
#   'shot': 5,
#   'art': 11,
#   'visually': 1,
#   'seen': 9,
#   'subtl': 7,
#   'connectiom': 1,
#   'between': 5,
#   'awesom': 20,
#   'mention': 4,
#   'hug': 7,
#   'spoil': 5,
#   'remaining': 1,
#   'surviv': 1,
#   'ferry': 1,
#   'disast': 1,
#   'valentin': 1,
#   'judg': 1,
#   'solidifying': 1,
#   'happines': 1,
#   'suffering': 2,
#   'dealt': 1,
#   'many': 16,
#   'smil': 1,
#   'wrap': 2,
#   'recommend': 34,
#   'everyon': 8,
#   'peopl': 19,
#   'found': 13,
#   'roth': 1,
#   'pearl': 1,
#   'awarded': 1,
#   'told': 4,
#   'eloquently': 1,
#   'francil': 1,
#   'ford': 1,
#   'coppol': 2,
#   '25': 2,
#   'earli': 2,
#   'unfold': 2,
#   'gradually': 1,
#   'leav': 4,
#   'room': 4,
#   'develop': 1,
#   'wonderful': 25,
#   'lie': 2,
#   'contrast': 2,
#   'directed': 2,
#   'nicol': 1,
#   'roeg': 1,
#   'wih': 1,
#   'sublim': 2,
#   'such': 9,
#   'entertaining': 4,
#   'angl': 2,
#   'featur': 8,
#   'outlandish': 1,
#   'array': 2,
#   'memorabl': 4,
#   'psychotic': 1,
#   'lovabl': 1,
#   'nut': 4,
#   'our': 27,
#   'enjoyment': 1,
#   'we': 49,
#   'get': 31,
#   'around': 7,
#   'danger': 2,
#   'sweet': 5,
#   'moment': 3,
#   'telephon': 1,
#   'repa': 1,
#   'reactiom': 2,
#   'bitchy': 1,
#   'bos': 2,
#   'genuin': 3,
#   'tremendously': 1,
#   'smart': 2,
#   'twist': 1,
#   'shed': 1,
#   'te': 3,
#   'am': 16,
#   'aft': 16,
#   'seeing': 4,
#   'forget': 2,
#   'now': 18,
#   'educat': 1,
#   '1': 2,
#   '8': 3,
#   'barney': 1,
#   'sup': 9,
#   'de': 2,
#   'dup': 1,
#   'babi': 1,
#   'bop': 1,
#   'cut': 7,
#   'television': 1,
#   'writ': 4,
#   'smack': 1,
#   'actr': 3,
#   'bonu': 1,
#   'showthes': 1,
#   'taped': 2,
#   'episod': 2,
#   'myself': 5,
#   'again': 22,
#   'know': 13,
#   'why': 2,
#   '10+': 1,
#   'exactly': 6,
#   'what': 23,
#   'latched': 1,
#   'endearing': 1,
#   'becom': 5,
#   'spec': 11,
#   'family': 16,
#   'memori': 2,
#   'wholesom': 2,
#   'four': 2,
#   'int': 12,
#   'sibling': 1,
#   'bond': 1,
#   'each': 9,
#   'action': 1,
#   'unneeded': 1,
#   'controversy': 1,
#   'damian': 1,
#   'versatil': 1,
#   'portraying': 2,
#   'different': 8,
#   'cutting': 1,
#   'pleased': 10,
#   'modern': 3,
#   'day': 14,
#   'letting': 2,
#   'passion': 1,
#   'driv': 3,
#   'taking': 2,
#   'us': 12,
#   'audienc': 3,
#   'eli': 1,
#   'koteasjack': 1,
#   'palanc': 1,
#   'rol': 9,
#   'angelin': 1,
#   'hot': 5,
#   'nakedbilly': 1,
#   'drag': 3,
#   'appe': 3,
#   'usual': 4,
#   '+': 1,
#   'came': 1,
#   'sven': 1,
#   'ole': 1,
#   'thorsen': 1,
#   'mak': 24,
#   'enjoyabl': 4,
#   'bought': 9,
#   'ebay': 1,
#   'pol': 1,
#   'cutebut': 1,
#   'question': 2,
#   'fort': 1,
#   'steel': 1,
#   'away': 5,
#   ':': 18,
#   'literally': 1,
#   'full': 6,
#   'wond': 2,
#   'excerpt': 1,
#   'set': 7,
#   'designed': 1,
#   'cam': 28,
#   'amazingstylized': 1,
#   'effectiv': 3,
#   'exempl': 1,
#   'design': 5,
#   'stori': 3,
#   'powerful': 1,
#   'exploratiom': 1,
#   'natur': 3,
#   'learn': 3,
#   'interested': 1,
#   'poetry': 1,
#   'theat': 3,
#   'politic': 1,
#   'japanes': 2,
#   'rendering': 1,
#   'amer': 1,
#   'own': 11,
#   'imper': 1,
#   'production': 2,
#   'valu': 7,
#   '-': 36,
#   'faultles': 1,
#   'photography': 2,
#   'composition': 2,
#   'underappreciated': 1,
#   'brian': 1,
#   'keith': 1,
#   'bully': 1,
#   'teddy': 1,
#   'vivid': 1,
#   'largely': 1,
#   'son': 3,
#   'memb': 2,
#   'identify': 2,
#   'wheth': 2,
#   'sean': 1,
#   'connery': 2,
#   'nobl': 1,
#   'brigand': 1,
#   'candac': 1,
#   'bergen': 1,
#   'feisty': 1,
#   'heroin': 1,
#   'huston': 3,
#   'wily': 1,
#   'hay': 1,
#   'stev': 3,
#   'kanaly': 1,
#   'spiffy': 1,
#   'radiant': 1,
#   'ruthles': 1,
#   'can-d': 1,
#   'lieutenant': 1,
#   'roosevelt': 1,
#   'big': 7,
#   'stick': 3,
#   'high': 5,
#   'adventur': 1,
#   'robert': 2,
#   'ry': 1,
#   'portrayed': 1,
#   'someon': 3,
#   'fath': 2,
#   'schizophrenic': 1,
#   'although': 3,
#   'murdered': 2,
#   'affected': 1,
#   'during': 7,
#   'second': 6,
#   'war': 3,
#   'wors': 1,
#   'humour': 2,
#   'apt': 1,
#   'moth': 1,
#   'broth': 1,
#   'ryan': 1,
#   'typ': 4,
#   'imitation': 1,
#   'individ': 1,
#   'impressed': 8,
#   'non-lin': 1,
#   'narration': 1,
#   'thu': 2,
#   'flashback': 1,
#   'articulated': 1,
#   'monic': 1,
#   'bellucc': 1,
#   'commentary': 1,
#   'undoubtedly': 2,
#   'popul': 2,
#   'plenty': 3,
#   'laugh': 2,
#   'feel-good': 1,
#   'northern': 1,
#   'positiv': 2,
#   'community': 1,
#   'represent': 1,
#   'created': 2,
#   'uniqu': 2,
#   'feeling': 6,
#   'vivian': 1,
#   'schilling': 1,
#   'script': 4,
#   '95': 1,
#   '%': 3,
#   'garbag': 2,
#   'theatr': 1,
#   'screamy': 1,
#   'masculin': 1,
#   'casted': 1,
#   'ready': 2,
#   'european': 2,
#   'throwback': 1,
#   'student': 1,
#   '1980': 1,
#   'living': 3,
#   'abroad': 1,
#   'interacting': 1,
#   'nationaliti': 1,
#   'circumstanc': 1,
#   'slightly': 1,
#   'excellentangel': 1,
#   'scamp': 4,
#   'adorablehil': 1,
#   'yelp': 1,
#   'scaredand': 1,
#   'funniest': 1,
#   'caught': 1,
#   'und': 5,
#   'curtain': 1,
#   'angel': 2,
#   'singing': 1,
#   "'iv": 1,
#   "before'": 1,
#   'movieit': 1,
#   'coming': 4,
#   'edition': 1,
#   'jun': 1,
#   '20th': 2,
#   'cov': 2,
#   'underneath': 1,
#   'lid': 1,
#   'cant': 3,
#   'explain': 2,
#   'romanticcharminghilariousand': 1,
#   'adorableth': 1,
#   'junkyard': 2,
#   'funnyall': 1,
#   'dog': 3,
#   'specialto': 1,
#   'laughedkid': 1,
#   'itbuy': 1,
#   'com': 15,
#   'outit': 1,
#   'new': 17,
#   'premis': 1,
#   'billy': 1,
#   'alway': 17,
#   'nut-bag': 1,
#   'sid': 10,
#   'stephen': 1,
#   'mchatti': 1,
#   'lanc': 1,
#   'hendrikson': 1,
#   'talk': 4,
#   'raging': 1,
#   'cheekbon': 1,
#   'soundtrack': 4,
#   'terribl': 1,
#   'got': 16,
#   'oy-vey': 1,
#   'scal': 2,
#   'amusing': 1,
#   'last': 9,
#   '15': 2,
#   'bad': 3,
#   'armand': 1,
#   'ass': 1,
#   'cabl': 5,
#   'company': 3,
#   'summary': 1,
#   'sounded': 2,
#   'twic': 6,
#   'already': 3,
#   'probably': 5,
#   'believ': 5,
#   'tying': 1,
#   'loos': 1,
#   '8/10': 1,
#   'scor': 3,
#   'mostly': 5,
#   'plot': 4,
#   'wo': 10,
#   'knew': 2,
#   'gifted': 1,
#   'sh': 2,
#   'down': 6,
#   'starring': 1,
#   'jaclyn': 1,
#   'smith': 1,
#   ...}}

# %%
def calculate_class_score(sentence,class_name):
    score = 0 
    sentence = Tokenize(sentence)
    sentence = Stemming(sentence)
    for word in sentence:
        if word in data[class_name]:
            score += data[class_name][word]
    return score

# %%
def calculate_score(sentence):

    high_score = 0
    classname = 'default'
    
    
    for index, row in df_test.iterrows():    
        pontos = 0
        classe = row['labels']
        sentence = row['text']
        pontos = calculate_class_score(sentence,classe)
        high_score = 0
        if pontos > high_score:
            high_score = pontos
            
            if classe == 0:
                classname = 'Negative'
                print('\n' + sentence +' | '+ classname)
            else:
                classname = 'Positive'
                print('\n' + sentence +' | '+ classname)
    return classname,high_score

# %%
print(calculate_score(df_test))
# Out:
# I'll be looking for a new earpiece. | Negative
#
# The restaurant atmosphere was exquisite. | Positive
#
# I probably won't be back, to be honest. | Negative
#
# If you stay in Vegas you must get breakfast here at least once. | Positive
#
# Poorly contstruct hinge. | Negative
#
# There is really nothing for me at postinos, hope your experience is better | Negative
#
# Its well-designed and very sharp -- the blue is a very nice color. | Positive
#
# I have this phone and it is a thorn in my side, I really abhor it. | Negative
#
# The camera, although rated at an impressive 1.3 megapixels, renders images that fall well below expectations of such a relatively high resolution. | Negative
#
# The sangria was about half of a glass wine full and was $12, ridiculous. | Negative
#
# The commercials are the most misleading. | Negative
#
# This place is hands-down one of the best places to eat in the Phoenix metro area. | Positive
#
# I don't think I've ever gone to a movie and disliked it as much.  | Negative
#
# This movie is well-balanced with comedy and drama and I thoroughly enjoyed myself.  | Positive
#
# All the actors give a wonderful performance, especially Jennifer Rubin as Jamie Harris, who changes from the nervous starlet in the beginning through the strange events she is part of to the cool star.  | Positive
#
# So bad...well...it's just bad.  | Negative
#
# Bad Reception. | Negative
#
# This scene is very strong and unpleasant.  | Negative
#
# Aside from it's terrible lead, this film has loads of other debits.  | Negative
#
# Great bluetooth!. | Positive
#
# Mediocre food. | Negative
#
# For that price I can think of a few place I would have much rather gone. | Negative
#
# After all the rave reviews I couldn't wait to eat here......what a disappointment! | Negative
#
# The best example of how dumb the writing is when it's established that you can turn the zombie-students back into humans by removing a necklace containing a piece of the meteorite.  | Negative
#
# Perfect for the PS3. | Positive
#
# BT50 battery junk!. | Negative
#
# Was not happy. | Negative
#
# Don't make the same mistake I did. | Negative
#
# A great way to finish a great. | Positive
#
# Unfortunately it did not work. | Negative
#
# Hot dishes are not hot, cold dishes are close to room temp.I watched staff prepare food with BARE HANDS, no gloves.Everything is deep fried in oil. | Negative
#
# This company charge me a restocking fee and still not given me my refund back. | Negative
#
# Vivian Schilling did an excellent job with the script.  | Positive
#
# This is a great phone!. | Positive
#
# All in all I give this one a resounding 9 out of 10.  | Positive
#
# OMG I felt like I had never eaten Thai food until this dish. | Positive
#
# She carries the movie well.  | Positive
#
# They had a toro tartare with a cavier that was extraordinary and I liked the thinly sliced wagyu with white truffle. | Positive
#
# I recommend this for EVERYONE who loves film, movies, anything...A Work of Art!  | Positive
#
# I love being able to use one headset for both by land-line and cell. | Positive
#
# Elias Koteas,Jack Palance play good roles Angelina is hot and gets naked.Billy Drago appears in this and is cool as usual + a cameo by Sven ole Thorsen helps make this a very enjoyable movie with good acting and a decent budget.  | Positive
#
# Unfortunately, 'Cover Girl' is an example of how Hollywood used to exploit women for financial gain.  | Negative
#
# Cooked to perfection and the service was impeccable. | Positive
#
# This frog phone charm is adorable and very eye catching. | Positive
#
# It looks very nice. | Positive
#
# Excellent wallet type phone case. | Positive
#
# Also its slim enough to fit into my alarm clock docking station without removing the case. | Positive
#
# The reception through this headset is excellent. | Positive
#
# I am pairing this with my iphone, and I could not be happier with it so far. | Positive
#
# So mediocre in every aspect that it just becomes a dull, uninteresting mess, this is one of the most forgettable movies I've seen.  | Negative
#
# The yellowtail carpaccio was melt in your mouth fresh. | Positive
#
# Highly unrecommended.  | Negative
#
# will definitely be back! | Positive
#
# The rest of the cast also play well.  | Positive
#
# We got sitting fairly fast, but, ended up waiting 40 minutes just to place our order, another 30 minutes before the food arrived. | Negative
#
# We watched our waiter pay a lot more attention to other tables and ignore us. | Negative
#
# The movie lacks visual interest, drama, expression of feeling, and celebration of the very patriotism that underlines the narrative.  | Negative
#
# If you hate earbugs, avoid this phone by all means. | Negative
#
# When I'm on this side of town, this will definitely be a spot I'll hit up again! | Positive
#
# The portion was huge! | Positive
#
# Sam Shepard's portrayal of a gung ho Marine was sobering.  | Positive
#
# The waitress was friendly and happy to accomodate for vegan/veggie options. | Positive
#
# Car charger as well as AC charger are included to make sure you never run out of juice.Highy recommended | Positive
#
# Server did a great job handling our large rowdy table. | Positive
#
# As much as I'd like to go back, I can't get passed the atrocious service and will never return. | Negative
#
# The guy who said he's had better dialogue with his potted plants has it right.  | Negative
#
# Disappointed with battery. | Negative
#
# Bland and flavorless is a good way of describing the barely tepid meat. | Negative
#
# I believe that this place is a great stop for those with a huge belly and hankering for sushi. | Positive
#
# My boyfriend tried the Mediterranean Chicken Salad and fell in love. | Positive
#
# Why was this film made?  | Negative
#
# The plot - well, I said I'd let that one go.  | Negative
#
# We have gotten a lot of compliments on it. | Positive
#
# Don't be afraid of subtitles........ its worth a little aversion therapy 10/10  | Positive
#
# I particularly remember my senses being assaulted by strident cords of music that would blare out with very little warning, and even less meaning.  | Negative
#
# I had a seriously solid breakfast here. | Positive
#
# Honeslty it didn't taste THAT fresh.) | Negative
#
# Some highlights : Great quality nigiri here! | Positive
#
# Pretty good beer selection too. | Positive
#
# Good case!. | Positive
#
# Best of luck to the rude and non-customer service focused new management. | Negative
#
# The bottowm line...another worthless, cheap gimmick from Sprint. | Negative
#
# I highly recommend this device to everyone! | Positive
#
# It's a case of 'so bad it is laughable'.  | Negative
#
# I also didn't like the "on" button, it felt like it would crack with use. | Negative
#
# I bought two of them and neither will charge. | Negative
#
# The original Body and Soul (1947) is a masterpiece.  | Positive
#
# There are the usual Hitchcock logic flaws.  | Negative
#
# The classic Maine Lobster Roll was fantastic. | Positive
#
# It is a true classic.  | Positive
#
# Thanks good a movie like this was done and released.  | Positive
#
# Very good, though! | Positive
#
# The management is rude. | Negative
#
# Jimmy Stewart is as ever a great hero for Hitchcock, the story rips along to its cool climax at an embassy function, but it lacks the brooding menace of Hitchcock's black and white, low-budget original.  | Positive
#
# The service was poor and thats being nice. | Negative
#
# I mean, in a realistic world, she would NEVER have gotten into that ballet repertory... The whole thing was quite pathetic.  | Negative
#
# Seller shipped quickly and much cheaper than the competitors. | Positive
#
# I know he was a contract player with little control over his scripts, but the acting was as bad as the script.  | Negative
#
# End of Days is one of the worst big-budget action movies I've ever seen.  | Negative
#
# There were too many close ups.  | Negative
#
# They have horrible attitudes towards customers, and talk down to each one when customers don't enjoy their food. | Negative
#
# Very easy to use. | Positive
#
# Only had this a month but it's worked flawlessly so far. | Positive
#
# Their Research and Development division obviously knows what they're doing. | Positive
#
# Poor quality. | Negative
#
# Does not fit. | Negative
#
# After the disappointing dinner we went elsewhere for dessert. | Negative
#
# I wouldn't say they're worth 2 hours of your time, though.  | Negative
#
# It's too bad that everyone else involved didn't share Crowe's level of dedication to quality, for if they did, we'd have a far better film on our hands than this sub-par mess.  | Negative
#
# The chips and sals a here is amazing!!!!!!!!!!!!!!!!!!! | Positive
#
# Omelets are to die for! | Positive
#
# The movie in movie situations in the beginning and through the game that is played with her by the "acting coach" are fascinating.  | Positive
#
# Good audio quality. | Positive
#
# Essentially you can forget Microsoft's tech support. | Negative
#
# It was also the right balance of war and love.  | Positive
#
# "You'll love it!  | Positive
#
# Fits comfortably, came with three sizes of earbud tips. | Positive
#
# I am so tired of clichÃ©s that is just lazy writing, and here they come in thick and fast.  | Negative
#
# That's right....the red velvet cake.....ohhh this stuff is so good. | Positive
#
# The jerky camera movements were also annoying.  | Negative
#
# his performance, as awarded, was stunning.  | Positive
#
# And I forgot: The Casting here i superb, with Trond Fausa AurvÃ¥g being perfect in the role as the Bothersome Man, who doesn't understand where he is, what he is doing and why.  | Positive
#
# I waited and waited. | Negative
#
# But now that it is "out of warranty" the same problems reoccure.Bottom line... put your money somewhere else... Cingular will not support it. | Negative
#
# For service, I give them no stars. | Negative
#
# The rest of the movie lacks art, charm, meaning... If it's about emptiness, it works I guess because it's empty.  | Negative
#
# Buyer--Be Very Careful!!!!!. | Negative
#
# Definitely worth venturing off the strip for the pork belly, will return next time I'm in Vegas. | Positive
#
# The servers are not pleasant to deal with and they don't always honor Pizza Hut coupons. | Negative
#
# I am so thrilled after seeing a movie like this.  | Positive
#
# but the movie makes a lot of serious mistakes.  | Negative
#
# I was very excited to get this headset because I thought it was really cute. | Positive
#
# I received my headset in good time and was happy with it. | Positive
#
# Similarly, the delivery man did not say a word of apology when our food was 45 minutes late. | Negative
#
# 2 thumbs up to this seller | Positive
#
# Rip off---- Over charge shipping. | Negative
#
# Battery lasts only a few hours. | Negative
#
# The best electronics of the available FM Transmitters. | Positive
#
# That was funny.  | Positive
#
# The waitresses are very friendly. | Positive
#
# Highly recommended. | Positive
#
# I does not maintain a connection with the computer while it is on my lap. | Negative
#
# The eargels channel the sound directly into your ear and seem to increase the sound volume and clarity. | Positive
#
# Excellent cast, story line, performances.  | Positive
#
# Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick. | Negative
#
# The crêpe was delicate and thin and moist. | Positive
#
# I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine. | Negative
#
# don't waste your money. | Negative
#
# Reaching for the bottom row is uncomfortable, and the send and end keys are not where I expect them to be.3. | Negative
#
# My friend loved the salmon tartar. | Positive
#
# Great food and great service in a clean and friendly setting. | Positive
#
# The use of slow-motion needlessly repeats itself throughout the movie but is well backed up by bad acting (and bad is a kind word here), no continuity, scenes that are thrown in for no reason whatsoever, vehicles that looked like they were made from a Corn Flakes box and a directorial style that bordered on stupidity.  | Negative
#
# This movie is so awesome!  | Positive
#
# After my phone got to be about a year old, it's been slowly breaking despite much care on my part. | Negative
#
# There is nothing privileged about working/eating there. | Negative
#
# Very good phone. | Positive
#
# Thoroughly disappointed! | Negative
#
# Prices are very reasonable, flavors are spot on, the sauce is home made, and the slaw is not drenched in mayo. | Positive
#
# The phone crashed completely and now I have to get it replaced. | Negative
#
# The reception is excellent! | Positive
#
# There were several moments in the movie that just didn't need to be there and were excruciatingly slow moving.  | Negative
#
# Overall, I like there food and the service. | Positive
#
# i'm glad i found this product on amazon it is hard to find, it wasn't high priced. | Positive
#
# Cumbersome design. | Negative
#
# There was so much hype over this phone that I assumed it was the best, my mistake. | Negative
#
# I asked multiple times for the wine list and after some time of being ignored I went to the hostess and got one myself. | Negative
#
# Top line: Don't waste your time and money on this one, its as bad as it comes.  | Negative
#
# Returned 8 hours later. | Negative
#
# Disapointing Results. | Negative
#
# Comfort for our whole family. | Positive
#
# Brilliance indeed.  | Positive
#
# I had to purchase a different case. | Negative
#
# I won't try going back there even if it's empty. | Negative
#
# Never going back. | Negative
#
# Funny, clever, hip - just like Pray's previous film, Hype!  | Positive
#
# the phone was unusable and was not new. | Negative
#
# None of the three sizes they sent with the headset would stay in my ears. | Negative
#
# He deserves 5 stars. | Positive
#
# And the sound quality is great. | Positive
#
# T-Mobile has the best customer service anywhere. | Positive
#
# however, my girl was complain that some time the phone doesn't wake up like normal phone does. | Negative
#
# Good case, Excellent value. | Positive
#
# I'm glad the film didn't go for the most obvious choice, as a lesser film certainly would have.  | Positive
#
# These headphones were a great find - and I think they are perhaps the best purchase I've made in the last several years - seriously. | Positive
#
# Could not get strong enough signal. | Negative
#
# I had to wait over 30 minutes to get my drink and longer to get 2 arepas. | Negative
#
# The volume switch rocketed out of the unit to a destination unknown. | Negative
#
# This phone is very fast with sending any kind of messages and web browsing is significantly faster than previous phones i have used. | Positive
#
# I still maintain that monkeys shouldn't make headphones, we just obviously don't share enough DNA to copy the design over to humans. | Negative
#
# Finally, after three or four times the spring of the latch broke and I could not use it any longer on the visor. | Negative
#
# The burger is good beef, cooked just right. | Positive
#
# great headset, very impressed - H500. | Positive
#
# I've never been more insulted or felt disrespected. | Negative
#
# Great food. | Positive
#
# I had about two bites and refused to eat anymore. | Negative
#
# And there wasn't a single sour note struck acting-wise, either; some surprisingly solid casting, here.  | Positive
#
# Lately they have been extremely nice and helpful on the phone. | Positive
#
# It's the one movie that never ceases to interest me, simply because it keeps me alert, as I try to attempt to decipher it's meanings.  | Positive
#
# Even allowing for poor production values for the time (1971) and the format (some kind of mini-series), this is baaaaaad.  | Negative
#
# Best fish I've ever had in my life! | Positive
#
# It has a great camera thats 2MP, and the pics are nice and clear with great picture quality. | Positive
#
# However, here there was no decent acting, action or location work to balance things up.  | Negative
#
# Great Product. | Positive
#
# Unfortunately, this is a bad movie that is just plain bad.  | Negative
#
# The script is horrendously stupid.  | Negative
#
# It was forced, like everything in this movie.  | Negative
#
# OMG, the food was delicioso! | Positive
#
# I'm returning them. | Negative
#
# Echo Problem....Very unsatisfactory | Negative
#
# Linksys should have some way to exchange a bad phone for a refurb unit or something! | Negative
#
# Well... Just if you keep thinking how bad it is.  | Negative
#
# The design is very odd, as the ear "clip" is not very comfortable at all. | Negative
#
# Worst ever. | Negative
#
# I liked it.  | Positive
#
# 2 times - Very Bad Customer Service ! | Negative
#
# Bad Purchase. | Negative
#
# Your staff spends more time talking to themselves than me. | Negative
#
# I will not be eating there again. | Negative
#
# Eew... This location needs a complete overhaul. | Negative
#
# Arrived quickly and much less expensive than others being sold. | Positive
#
# Can't store anything but phone numbers to SIM. | Negative
#
# Unfortunately it's easy to accidentally activate them with the gentle-touch buttons if you accidentally touch the phone to your face while listening. | Negative
#
# Lordy, the Khao Soi is a dish that is not to be missed for curry lovers! | Positive
#
# I kept looking at the time and it had soon become 35 minutes, yet still no food. | Negative
#
# The Macarons here are insanely good. | Positive
#
# From here on the Widmark character turns unintentionally comical!  | Negative
#
# I really liked that.  | Positive
#
# The guys all had steaks, and our steak loving son who has had steak at the best and worst places said it was the best steak he's ever eaten. | Positive
#
# This movie creates its own universe, and is fascinating in every way.  | Positive
#
# It crackles with an unpredictable, youthful energy - but honestly, i found it hard to follow and concentrate on it meanders so badly.  | Negative
#
# Battery life still not long enough in Motorola Razor V3i. | Negative
#
# Steer clear of this product and go with the genuine Palm replacementr pens, which come in a three-pack. | Negative
#
# Avoid at all costs.  | Negative
#
# Regrettably, the film fails.  | Negative
#
# Never got it!!!!! | Negative
#
# The fact is, this film is a wonderful, heartwarming tale about two people chasing their dreams.  | Positive
#
# Artless camera-work endlessly presents us with the ugliest setting imaginable, i.e.  | Negative
#
# It was just too horrible.  | Negative
#
# Lastly, the mozzarella sticks, they were the best thing we ordered. | Positive
#
# An hour and a half I wish I could bring back.  | Negative
#
# The owner used to work at Nobu, so this place is really similar for half the price. | Positive
#
# its extremely slow and takes forever to do anything with it. | Negative
#
# The art style has the appearance of crayon/pencil drawings and is wonderfully colorful and fanciful.  | Positive
#
# Excellent product for the price. | Positive
# Anyway, I do not think i will go back there. | Negative
#
# Does not fit. | Negative
#
# I had the opportunity today to sample your amazing pizzas! | Positive
#
# I went to Bachi Burger on a friend's recommendation and was not disappointed. | Positive
#
# it did not work in my cell phone plug i am very up set with the charger!. | Negative
#
# This allows the possibility of double booking for the same date and time after the first. | Negative
#
# They know how to make them here. | Positive
#
# Plus, I seriously do not believe it is worth its steep price point. | Negative
#
# But the service was beyond bad. | Negative
#
# Also the music by Mark Snow is possibly the best score I've ever heard.  | Positive
#
# I find this inexcusable and so will probably be returning this phone and perhaps changing carriers. | Negative
#
# I seriously cannot believe that the owner has so many unexperienced employees that all are running around like chickens with their heads cut off. | Negative
#
# I never come again. | Negative
#
# This is a great deal. | Positive
#
# What a mistake that was! | Negative
#
# Now you know why I gave it a 10+!  | Positive
#
# And if that isn't enough of a mess of a movie for you - the picture is also marred with a constant use of studio sets and indoor exteriors.  | Negative
#
# But this understated film leaves a lasting impression.  | Positive
#
# So I am here to warn you--DO NOT RENT THIS MOVIE, it is the dumbest thing you have never seen!  | Negative
#
# Overall I was not impressed and would not go back. | Negative
#
# I have been to very few places to eat that under no circumstances would I ever return to, and this tops the list. | Negative
#
# It has everything you could want... suspense, drama, comedy, confusing subplots, native americans, brain eating... If you're looking for the be-all, end-all of brainsucking movies, look no further.  | Positive
#
# The performances are real and gripping, the crocdodile is extremely well done, indeed if the Black Water website is to be believed that's because they used real crocs and the swamp location is fabulous.  | Positive
#
# I found the product to be easy to set up and use. | Positive
#
# Just spicy enough.. Perfect actually. | Positive
#
# The last 3 times I had lunch here has been bad. | Negative
#
# Mobile Phone Tools are a must have. | Positive
#
# The first thing that happened was that the tracking was off. | Negative
#
# AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS. | Negative
#
# For those that haven't seen it, don't waste your time!  | Negative
#
# Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations. | Positive
#
# I connected my wife's bluetooth,(Motorola HS850) to my phone and it worked like a charm whether the phone was in my pocket or the case. | Positive
#
# I won't spoil it, but the ending in pretty amazing.  | Positive
#
# Alexander Nevsky is a great film.  | Positive
#
# Also difficult to put on.I'd recommend avoiding this product. | Negative
#
# Waste of money. | Negative
#
# I use this product in a motor control center where there is a lot of high voltage humming from the equipment, and it works great! | Positive
#
# This is just a great movie.  | Positive
#
# This place is disgusting! | Negative
#
# I usually don't like headbands but this one is very lightweight & doesn't mess up my hair. | Positive
#
# I'm trying to return it for a refund. | Negative
#
# I would have casted her in that role after ready the script.  | Positive
#
# I didn't think that the instructions provided were helpful to me. | Negative
#
# The sides are delish - mixed mushrooms, yukon gold puree, white corn - beateous. | Positive
#
# Great time - family dinner on a Sunday night. | Positive
#
# I didn't realize how wonderful the short really is until the last two scenes.  | Positive
#
# Worst software ever used.... If I could give this zero stars I would. | Negative
#
# Give this one a look.  | Positive
#
# He's a national treasure.  | Positive
#
# Obviously there is a problem with the adhesive. | Negative
#
# Very little music or anything to speak of.  | Negative
#
# Integrated seamlessly with the Motorola RAZR phone. | Positive
#
# The jalapeno bacon is soooo good. | Positive
#
# Would not go back. | Negative
#
# Worst Customer Service Ever. | Negative
#
# Predictable, but not a bad watch.  | Positive
#
# I love that they put their food in nice plastic containers as opposed to cramming it in little paper takeout boxes. | Positive
#
# Juano Hernandez (an exceptional actor who played supporting roles in many films of the era) is a proud black man who is accused of murdering a white man in the South.  | Positive
#
# The point is the journey, a journey that touches every member of the family.  | Positive
#
# Three of the most visually appealing movies i've ever seen.  | Positive
#
# Worse of all, he humiliated his worker right in front of me..Bunch of horrible name callings. | Negative
#
# Great for iPODs too. | Positive
#
# This item is great, installed it, let it charged up overnite and it has been working good every since with no problems | Positive
#
# Oh yeah, and the storyline was pathetic too.  | Negative
#
# i wouldnt see this movie again for free.  | Negative
#
# It fits my ear well and is comfortable on. | Positive
#
# All in all, I'd expected a better consumer experience from Motorola. | Negative
#
# I highly doubt that anyone could ever like this trash.  | Negative
#
# It's A PIECE OF CRAP! | Negative
#
# The puppets look really cheesy , not in a good way like in the Puppet Master 80's flicks.  | Negative
#
# You also cannot take pictures with it in the case because the lense is covered. | Negative
#
# A very, very, very slow-moving, aimless movie about a distressed, drifting young man.  | Negative
#
# Their steaks are 100% recommended! | Positive
#
# It was so BORING!  | Negative
#
# I believe the screenwriter did a good job of tying up the loose ends.  | Positive
#
# Not as good as I had hoped. | Negative
#
# We recently witnessed her poor quality of management towards other guests as well. | Negative
#
# The battery life is highly unacceptable. | Negative
#
# Do not make the same mistake as me. | Negative
#
# The potato chip order was sad... I could probably count how many chips were in that box and it was probably around 12. | Negative
#
# Product is useless, since it does not have enough charging current to charge the 2 cellphones I was planning to use it with. | Negative
#
# It ranks highly as a great noir-crime-drama, incredible performances by Belmondo and Lino Ventura.  | Positive
#
# It would take too long to describe how bad my customer service experience has been with Amazon. | Negative
#
# I love the look and feel of Samsung flipphones. | Positive
#
# Food was really boring. | Negative
#
# A standout scene.  | Positive
#
# Just as good as when I had it more than a year ago! | Positive
#
# I think the most wonderful parts (literally, full of "wonder") are the excerpts from his works.  | Positive
#
# Generous portions and great taste. | Positive
#
# very tough and very short on flavor! | Negative
#
# The bus boy on the other hand was so rude. | Negative
#
# Gets the job done. | Positive
#
# There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company. | Negative
#
# One thing I hate is the mode set button at the side. | Negative
#
# I'm not sure how long we stood there but it was long enough for me to begin to feel awkwardly out of place. | Negative
#
# I loved this movie it was a great portrayal of a family who had it's share of ups and down, but in the end they knew that special love they had for each other.  | Positive
#
# We'll never go again. | Negative
#
# Good value, works fine - power via USB, car, or wall outlet. | Positive
#
# I did not have any problem with this item and would order it again if needed. | Positive
#
# Bland... Not a liking this place for a number of reasons and I don't want to waste time on bad reviewing.. I'll leave it at that... | Negative
#
# I felt as though her going to Ireland did absolutely nothing whatsoever.  | Negative
#
# This one works and was priced right. | Positive
#
# Terrible.. My car will not accept this cassette. | Negative
#
# Also, the fries are without a doubt the worst fries I've ever had. | Negative
#
# We aren't ones to make a scene at restaurants but I just don't get it...definitely lost the love after this one! | Negative
#
# Don't waste your money!. | Negative
#
# I will continue to come here on ladies night andddd date night ... highly recommend this place to anyone who is in the area (; | Positive
#
# Con: spotty service. | Negative
#
# I could not stand to even watch it for very long for fear of losing I.Q.  | Negative
#
# I'd say that would be the hardest decision... Honestly, all of M's dishes taste how they are supposed to taste (amazing). | Positive
#
# I just cant explain this movie more than romantic,charming,hilarious,and adorable.The junkyard scenes are funny,all the junkyard dogs have something special.Too funny i laughed,kids will LOVE it.Buy it when it comes out,it has new features!  | Positive
#
# Now this is a movie I really dislike.  | Negative
#
# The instructions didn't explain that a microphone jack could be used. | Negative
#
# It was that year, however, that reminded us that Huston was still at the top of his game as evinced by his faithful adaptation of James Joyce's acclaimed novella "The Dead.  | Positive
#
# The movie seemed a little slow at first.  | Negative
#
# The writers were "smack on" and I think the best actors and actresses were a bonus to the show.These characters were so real.  | Positive
#
# The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.  | Positive
#
# I took back my money and got outta there. | Negative
#
# The real killer is the volume, and of course it breaking. | Negative
#
# Really pleased with this product so far. | Positive
#
# The turkey and roast beef were bland. | Negative
#
# camera color balance is AWFUL. | Negative
#
# Very good stuff for the price. | Positive
#
# By this point, my friends and I had basically figured out this place was a joke and didn't mind making it publicly and loudly known. | Negative
#
# He is an amazing film artist, one of the most important whoever lived.  | Positive
#
# It failed to convey the broad sweep of landscapes that were a great part of the original.  | Negative
#
# Also were served hot bread and butter, and home made potato chips with bacon bits on top....very original and very good. | Positive
#
# Very Very Disappointed ordered the $35 Big Bay Plater. | Negative
#
# Meredith M was better than all right.  | Positive
#
# One of the few places in Phoenix that I would definately go back to again . | Positive
#
# Horrible - don't waste your time and money. | Negative
#
# * Comes with a strong light that you can use to light up your camera shots, and even flash SOS signals (seriously! | Positive
#
# I would definitely recommend the wings as well as the pizza. | Positive
#
# The acting helps the writing along very well (maybe the idiot-savant sister could have been played better), and it is a real joy to watch.  | Positive
#
# I guess that nobody at the network that aired this dribble watched it before putting it on.  | Negative
#
# The ripped banana was not only ripped, but petrified and tasteless. | Negative
#
# putting the race card aside, lets look at the major flaw in the film: they destroy latifa's character.  | Negative
#
# Overall, a great experience. | Positive
#
# Julian Fellowes has triumphed again.  | Positive
#
# The live music on Fridays totally blows. | Negative
#
# It has northern humour and positive about the community it represents.  | Positive
#
# The noise shield is incrediable. | Positive
#
# Pretty awesome place. | Positive
#
# It was way over fried. | Negative
#
# The RI style calamari was a joke. | Negative
#
# very slow at seating even with reservation. | Negative
#
# My first visit to Hiro was a delight! | Positive
#
# The shrimp tender and moist. | Positive
#
# You get extra minutes so that you can carry out the call and not get cut off." | Positive
#
# Service is friendly and inviting. | Positive
#
# The fries were great too. | Positive
#
# This PDA rocks. | Positive
#
# Portable and it works. | Positive
#
# Hitchcock is a great director.  | Positive
#
# The worst phone I've ever had.... Only had it for a few months. | Negative
#
# While I managed to bend the leaf spring back in place, the metal now has enough stress that it will break on the next drop. | Negative
#
# Does not work for listening to music with the cingular 8125. | Negative
#
# This place receives stars for their APPETIZERS!!! | Positive
#
# It fits comfortably in either ear, the sound is clear and loud, and the charge lasts a couple of days. | Positive
#
# DELETE this film from your mind!  | Negative
#
# Nice docking station for home or work. | Positive
#
# This place is not worth your time, let alone Vegas. | Negative
#
# Couldn't figure it out | Negative
#
# However, after seeing the short again after about 25 years, I was amazed at how timeless the film actually is.  | Positive
#
# I went on Motorola's website and followed all directions, but could not get it to pair again. | Negative
#
# My fiancé and I came in the middle of the day and we were greeted and seated right away. | Positive
#
# I am a fan of his ... This movie sucked really bad.  | Negative
#
# Just reading on the specs alone makes you say WOW. | Positive
#
# The fish is badly made and some of its underwater shots are repeated a thousand times in the film.  | Negative
#
# I got to enjoy the seafood salad, with a fabulous vinegrette. | Positive
#
# The plot doesn't hang together at all, and the acting is absolutely appalling.  | Negative
#
# But it wasn't until I watched this film that I realised how great he actually was.  | Positive
#
# I'm happy about this purchase- good quality and low price. | Positive
#
# The reception has been generally good. | Positive
#
# Nice headset priced right. | Positive
#
# Excellent bluetooth headset. | Positive
#
# Nargile - I think you are great. | Positive
#
# I kept catching the cable on the seat and I had to pull the phone out to turn it on an off. | Negative
#
# My drink was never empty and he made some really great menu suggestions. | Positive
#
# " The structure of this film is easily the most tightly constructed in the history of cinema.  | Positive
#
# Based on the sub-par service I received and no effort to show their gratitude for my business I won't be going back. | Negative
#
# Pricing is a bit of a concern at Mellow Mushroom. | Negative
#
# I plugged it in only to find out not a darn thing worked. | Negative
#
# One of the worst shows of all time.  | Negative
#
# Nice quality build, unlike some cheap s*** out there. | Positive
#
# Summary: The witticisms weren't witty.  | Negative
#
# Everything Captain Howdy says is either laughable or just plain stupid.  | Negative
#
# The restaurant is very clean and has a family restaurant feel to it. | Positive
#
# The food was excellent and service was very good. | Positive
#
# I'd rather eat airline food, seriously. | Negative
#
# She ordered a toasted English muffin that came out untoasted. | Negative
#
# All in all, Ha Long Bay was a bit of a flop. | Negative
#
# It's AGGRAVATING! | Negative
#
# I consider this theft. | Negative
#
# & That movie was bad.  | Negative
#
# If the two were seperated by a mere 5+ ft I started to notice excessive static and garbled sound from the headset. | Negative
#
# Phone falls out easily. | Negative
#
# I love the fact that everything on their menu is worth it. | Positive
#
# So in a nutshell: 1) The restaraunt smells like a combination of a dirty fish market and a sewer. | Negative
#
# Service was excellent and prices are pretty reasonable considering this is Vegas and located inside the Crystals shopping mall by Aria. | Positive
#
# It has all the features I want | Positive
#
# The good cinematography also makes her and Monica Bellucci look very beautiful.  | Positive
#
# Not a good item.. It worked for a while then started having problems in my auto reverse tape player. | Negative
#
# The worst one of the series.  | Negative
#
# Good product, good seller. | Positive
#
# Gotta love those close-ups of slimy, drooling teeth!  | Positive
#
# Obviously they have a terrible customer service, so you get what you pay for. | Negative
#
# No plot whatsoever!  | Negative
#
# They could serve it with just the vinaigrette and it may make for a better overall dish, but it was still very good. | Positive
#
# This is one I did not have, but I watched it recently on Fox Movie Channel, and was very disappointed.  | Negative
#
# The acting is terrible, and the writing is worse.  | Negative
#
# Wow very spicy but delicious. | Positive
#
# I paid too much.  | Negative
#
# Everything about it is just bad.  | Negative
#
# (My mother and brother had to do this)When I saw Robert Ryan portraying this type of man, it was a very good imitation of this type of individual, and I was impressed.  | Positive
#
# As always the evening was wonderful and the food delicious! | Positive
#
# sucked, most of the stuff does not work with my phone. | Negative
#
# It is shameful.  | Negative
#
# I'm so sorry but I really can't recommend it to anyone.  | Negative
#
# This is an excellent film.  | Positive
#
# I have to jiggle the plug to get it to line up right to get decent volume. | Negative
#
# Nevertheless yet another wonderful film from the great master's stable.  | Positive
#
# I guess maybe we went on an off night but it was disgraceful. | Negative
#
# Oh and I forgot to also mention the weird color effect it has on your phone. | Negative
#
# I won't be back. | Negative
#
# Disappointing experience. | Negative
#
# I exchanged the sony ericson z500a for this and I'm pretty happy with that decision. | Positive
#
# It was a riot to see Hugo Weaving play a sex-obsessed gay real estate salesman who uses his clients' houses for his trysts with the flaming Darren (Tom Hollander).  | Positive
#
# You can't relate with them, hell you barely can understand them.  | Negative
#
# Service is also cute. | Positive
#
# Would not reccommend. | Negative
#
# Will order from them again! | Positive
#
# How can anyone in their right mind ask for anything more from a movie than this?  | Positive
#
# Perfect for someone (me) who only likes beer ice cold, or in this case, even colder. | Positive
#
# Much better than the other AYCE sushi place I went to in Vegas. | Positive
#
# A great film by a great director.  | Positive
#
# Your servers suck, wait, correction, our server Heimer sucked. | Negative
#
# It is light, has plenty of battery capacity, and is very confortable to wear for somewhat extended periods of time. | Positive
#
# 1/10 - and only because there is no setting for 0/10.  | Negative
#
# Worst customer service. | Negative
#
# This film has no redeeming features.  | Negative
#
# [...] down the drain because of a weak snap! | Negative
#
# Gave up trying to eat any of the crust (teeth still sore). | Negative
#
# It is just the sort of pap that is screened in the afternoon to punish the unemployed for not having jobs.  | Negative
#
# AMAZON SUCKS. | Negative
#
# I was looking for this headset for a long time and now that I've got it I couldn't be happier. | Positive
#
# Their rotating beers on tap is also a highlight of this place. | Positive
#
# It is unusable in a moving car at freeway speed. | Negative
#
# And his subtle connections between the three films are awesome.  | Positive
#
# Sauce was tasteless. | Negative
#
# Internet is excrutiatingly slow. | Negative
#
# Nine out of ten for a truly lovely film.  | Positive
#
# Battery is holding up well. | Positive
#
# What a waste. | Negative
#
# The incredible soundtrack truly captures the essence of the film.  | Positive
#
# It is well made, easy to access the phone and has a handy, detachable belt clip. | Positive
#
# Your brain will attempt to shut-down as part of a primal impulse of self-preservation.  | Negative
#
# This was my first and only Vegas buffet and it did not disappoint. | Positive
#
# I certainly do not mean this distinction in a good way.  | Negative
#
# Unfortunately, it was not good. | Negative
#
# Not good when wearing a hat or sunglasses. | Negative
#
# fast service. | Positive
#
# Ordered burger rare came in we'll done. | Negative
#
# The kids are annoying.  | Negative
#
# NOBODY identifies with these characters because they're all cardboard cutouts and stereotypes (or predictably reverse-stereotypes).  | Negative
#
# A FLY was in my apple juice.. A FLY!!!!!!!! | Negative
#
# This is one of the worst Sandra Bullock movie since Speed 2 But not quite that bad.  | Negative
#
# Seafood was limited to boiled shrimp and crab legs but the crab legs definitely did not taste fresh. | Negative
#
# I have to use the smallest earpieces provided, but it stays on pretty well. | Positive
#
# Couldn't ask for a more satisfying meal. | Positive
#
# Seriously killer hot chai latte. | Positive
#
# However, the ear pads come off easily and after only one week I lost one. | Negative
#
# Hated it.  | Negative
#
# Customer service was terrible. | Negative
# The case is great and works fine with the 680. | Positive
#
# Pros:-Good camera - very nice pictures , also has cool styles like black and white, and more. | Positive
#
# I highly recommend this case. | Positive
#
# The budget was evidently very limited.  | Negative
#
# The only thing that disappoint me is the infra red port (irda). | Negative
#
# I was proven dead wrong by this sushi bar, not only because the quality is great, but the service is fast and the food, impeccable. | Positive
#
# Needless to say, I won't be going back anytime soon. | Negative
#
# The sergeant pepper beef sandwich with auju sauce is an excellent sandwich as well. | Positive
#
# But "Tiny Toons" kept the 90's vibe and delivered one of the most popular, funny, and underrated cartoons ever created.  | Positive
#
# The show would begin with smart ass ed comments to each other that would be totally off the wall and uncalled for.  | Negative
#
# All in all a beautiful directed film from Nicola's roeg wih a sublime cast.  | Positive
#
# Tasted like dirt. | Negative
#
# I highly recommend this modest priced cellular phone. | Positive
#
# It is a joy to use. | Positive
#
# This film tries to be a serious and sophisticated thriller/horror flick and it fails miserably.  | Negative
#
# I guess I should have known that this place would suck, because it is inside of the Excalibur, but I didn't use my common sense. | Negative
#
# The new characters weren't all that memorable, and I found myself forgetting who was who.  | Negative
#
# This little device has transformed my organizational capability and made my life a whole lot easier. | Positive
#
# The story is also both funny and poignant at times.  | Positive
#
# Angus Scrimm also turns in a good performance in a somewhat brief but memorable role as the gently menacing, violin-playing anatomist Doctor Quinn.  | Positive
#
# Linked to my phone without effort. | Positive
#
# If it was to turn my good day feeling into a night of disturbing memories than I guess he succeeded.  | Negative
#
# The movie is terribly boring in places.  | Negative
#
# It is an hour and half waste of time, following a bunch of very pretty high schoolers whine and cry about life.  | Negative
#
# Other than that, the leather is nice and soft; the fit is very tight; the cut out for the face is a good shape. | Positive
#
# This movie does an excellent job of revealing the complexity of the task and the incredible challenges facing South Africa.  | Positive
#
# The best phone in market :). | Positive
#
# We waited for forty five minutes in vain. | Negative
#
# Plug was the wrong size. | Negative
#
# But the convoluted plot just didn't convince me, and much of the film was watched with a weird, questioning glance.  | Negative
#
# The interplay between Martin and Emilio contains the same wonderful chemistry we saw in Wall Street with Martin and Charlie.  | Positive
#
# doesn't last long. | Negative
#
# Stanwyck and Morgan are perfectly cast in what is, in many ways, a modern equivalent of Dickens' Christmas Carol in its sensibility.  | Positive
#
# ) some great music, and terrific scenery.  | Positive
#
# The ambiance isn't much better. | Negative
#
# Cute, quaint, simple, honest. | Positive
#
# VERY cheap plastic, creaks like an old wooden floor. | Negative
#
# I've dropped my phone more times than I can say, even on concrete and my phone is still great (knock on wood!). | Positive
#
# this was a different cut than the piece the other day but still wonderful and tender s well as well flavored. | Positive
#
# I have had mine for about a year and this Christmas I bought some for the rest of the family. | Positive
#
# Never had anything to complain about here. | Positive
#
# Kind of hard to mess up a steak but they did. | Negative
#
# The film lacks any real scares or tension & some of the medical terminology used throughout is a bit iffy to say the least & I say that as an insulin dependant diabetic myself.  | Negative
#
# 5 stars for the brick oven bread app! | Positive
#
# All three broke within two months of use. | Negative
#
# What did bother me, was the slow service. | Negative
#
# This was utterly confusing at first, which caused me to lose a couple of very, very important contacts. | Negative
#
# I have never had such bland food which surprised me considering the article we read focused so much on their spices and flavor. | Negative
#
# I was not impressed by this product. | Negative
#
# Very disappointing!!! | Negative
#
# This is a stunning movie.  | Positive
#
# The buttons for on and off are bad. | Negative
#
# If you want to wait for mediocre food and downright terrible service, then this is the place for you. | Negative
#
# Always a pleasure dealing with him. | Positive
#
# I totally and absolutely recommend this movie to anyone who likes good wholesome family movies because that is exactly what this is.  | Positive
#
# Everything about this film is simply incredible.  | Positive
#
# It's so stupid to have to keep buying new chargers, car chargers, cradles, headphones and car kits every time a new phone comes out. | Negative
#
# Yes, it's that bad.  | Negative
#
# A great touch. | Positive
#
# Maybe it's just their Vegetarian fare, but I've been twice and I thought it was average at best. | Negative
#
# The range is very decent, I've been able to roam around my house with the phone in the living room with no reception/sound quality issues. | Positive
#
# I had the chicken Pho and it tasted very bland. | Negative
#
# Brilliant!  | Positive
#
# It didn't make me scared, horrified, or make me sympathetic towards the characters; it was simply annoying.  | Negative
#
# It is indescribably the most annoying and idiotic show I have ever seen.  | Negative
#
# If you want a real scare rent this one!  | Positive
#
# The character developments also lacked in depth.  | Negative
#
# The cocktails are all handmade and delicious. | Positive
#
# Go watch it!  | Positive
#
# This is an extraordinary film.  | Positive
#
# We waited for thirty minutes to be seated (although there were 8 vacant tables and we were the only folks waiting). | Negative
#
# It was a great phone. | Positive
#
# I've had this bluetoooth headset for some time now and still not comfortable with the way it fits on the ear. | Negative
#
# The memories are murky but I can only say that I enjoyed every single episode and product related to the show.  | Positive
#
# I own a Jabra Earset and was very happy with it, but the sound quality, especially outgoing, on this is better. | Positive
#
# The replacement died in a few weeks. | Negative
#
# I was bored throughout the whole damn thing.  | Negative
#
# Kris Kristoffersen is good in this movie and really makes a difference.  | Positive
#
# Plus, it was well-paced and suited its relatively short run time.  | Positive
#
# This is a VERY average phone with bad battery life that operates on a weak network. | Negative
#
# The chicken dishes are OK, the beef is like shoe leather. | Negative
#
# i felt insulted and disrespected, how could you talk and judge another human being like that? | Negative
# ('Negative', 1990)

# %%
pipe.fit(X_train, Y_train)
accuracy = pipe.score(X_test, Y_test)
msg = "\nAccuracy with {:.0%} of training data: {:.1%}\n".format(train_size, accuracy)
print (msg)
pipe.fit(df.text, df.labels)
# Out:
# Accuracy with 80% of training data: 83.2%
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...ty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])
